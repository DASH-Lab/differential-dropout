# %%
import torch
import torch.nn as nn  
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report
import ResNet as resnet
import DenseNet as densenet
import EfficientNet as efficientnet
import MobileNetV2 as mobilenet
import ViT as vit
import solver.solver as solver
import solver.solver_v2 as solver_v2
import solver.solver_v3 as solver_v3

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2, 3"

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

n_epochs = 30
batch_size = 64
learning_rate = 1e-4
diff_drop = "v0"

model = resnet.resnet18(num_classes=10, diff_drop=diff_drop).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_path = "/media/data1/hyunjun/cifar-10/train/"
test_path = "/media/data1/hyunjun/cifar-10/test/"

# %%
trans = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.491, 0.482, 0.447), (0.247, 0.243, 0.262)),
])

trainset = torchvision.datasets.ImageFolder(root=train_path, transform=trans)
testset = torchvision.datasets.ImageFolder(root=test_path, transform=trans)

train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, drop_last=False, )
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=True, drop_last=False, )

classes = trainset.classes
print(classes)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def train_loop(dataloader, model, criterion, optimizer, epoch):
    size = len(dataloader.dataset)
    total_correct = 0
    total_loss = 0
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        model.train()
        correct = 0
        
        pred = None
        p = 0.0
        if diff_drop == "v3":
            pred, p = model(X.to(device), epoch)
        else:
            pred, p = model(X.to(device))
        
        loss = criterion(pred, y.to(device))
        correct += (torch.argmax(pred, dim=1) == y.to(device)).type(torch.float).sum().item()
        total_correct += correct
        
        model.train()
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        
        if diff_drop == "v1":
            solver.PseudoPruning(model.fc, p)
        elif diff_drop == "v2":
            solver_v2.PseudoPruning(model.fc, p)
        elif diff_drop == "v3":
            solver_v3.PseudoPruning(model.fc, p)
        
        optimizer.step()
        
        if (batch % 50 == 0):
            print(f"Batch {batch:>5d}: Loss per batch is {loss.item():>7.6f} and Accuracy is {correct / batch_size:>7.6f}")
    print(f"For Iteration: Loss is {(total_loss / (size // batch_size)):>7.6f} and Accuracy is {total_correct / size:>7.6f}")

# %%
def test_loop(dataloader, model, criterion):
    test_loss = 0
    correct = 0

    model.eval()
    
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for X, y in dataloader:
            pred, _ = model(X.to(device))
            test_loss += criterion(pred, y.to(device)).item()
            
            pred = torch.argmax(pred, dim=1)
            correct += (pred == y.to(device)).type(torch.float).sum().item()
            
            pred = pred.cpu().numpy()
            y = y.cpu().numpy()
            y_true.extend(y)
            y_pred.extend(pred)
    
    print(classification_report(y_true=y_true, y_pred=y_pred, target_names=classes))
    
    return correct / len(dataloader.dataset)

# %%
max = 0.0
for epoch in range(n_epochs):
    print(f"Training: Epoch {epoch + 1} ------------------")
    train_loop(train_loader, model, criterion, optimizer, epoch + 1)
    print(f"----Test: Epoch {epoch + 1} ------------------")
    temp = test_loop(test_loader, model, criterion)
    
    if temp > max:
        max = temp
        torch.save(model, './cifar10_resnet18_nothing.pt')
# Out:
# Training: Epoch 1 ------------------
# Batch     0: Loss per batch is 2.350599 and Accuracy is 0.031250
# Batch    50: Loss per batch is 1.837452 and Accuracy is 0.359375
# Batch   100: Loss per batch is 1.670153 and Accuracy is 0.328125
# Batch   150: Loss per batch is 1.640617 and Accuracy is 0.468750
# Batch   200: Loss per batch is 1.303082 and Accuracy is 0.500000
# Batch   250: Loss per batch is 1.392949 and Accuracy is 0.531250
# Batch   300: Loss per batch is 1.324533 and Accuracy is 0.578125
# Batch   350: Loss per batch is 1.216123 and Accuracy is 0.500000
# Batch   400: Loss per batch is 1.481932 and Accuracy is 0.453125
# Batch   450: Loss per batch is 1.160752 and Accuracy is 0.625000
# Batch   500: Loss per batch is 1.195169 and Accuracy is 0.531250
# Batch   550: Loss per batch is 1.320340 and Accuracy is 0.546875
# Batch   600: Loss per batch is 1.324061 and Accuracy is 0.515625
# Batch   650: Loss per batch is 0.901438 and Accuracy is 0.734375
# Batch   700: Loss per batch is 1.355691 and Accuracy is 0.531250
# Batch   750: Loss per batch is 0.960360 and Accuracy is 0.765625
# For Iteration: Loss is 1.359978 and Accuracy is 0.506000
# ----Test: Epoch 1 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.52      0.72      0.61      1000
#   automobile       0.50      0.90      0.64      1000
#         bird       0.35      0.59      0.44      1000
#          cat       0.48      0.34      0.40      1000
#         deer       0.76      0.15      0.25      1000
#          dog       0.55      0.61      0.58      1000
#         frog       0.69      0.58      0.63      1000
#        horse       0.63      0.65      0.64      1000
#         ship       0.68      0.79      0.73      1000
#        truck       0.95      0.07      0.14      1000
#
#     accuracy                           0.54     10000
#    macro avg       0.61      0.54      0.51     10000
# weighted avg       0.61      0.54      0.51     10000
#
# Training: Epoch 2 ------------------
# Batch     0: Loss per batch is 1.068567 and Accuracy is 0.656250
# Batch    50: Loss per batch is 0.972287 and Accuracy is 0.625000
# Batch   100: Loss per batch is 1.000703 and Accuracy is 0.609375
# Batch   150: Loss per batch is 1.072046 and Accuracy is 0.640625
# Batch   200: Loss per batch is 0.763660 and Accuracy is 0.718750
# Batch   250: Loss per batch is 1.083117 and Accuracy is 0.640625
# Batch   300: Loss per batch is 0.802930 and Accuracy is 0.750000
# Batch   350: Loss per batch is 0.841518 and Accuracy is 0.687500
# Batch   400: Loss per batch is 0.851981 and Accuracy is 0.703125
# Batch   450: Loss per batch is 0.851953 and Accuracy is 0.718750
# Batch   500: Loss per batch is 0.932032 and Accuracy is 0.687500
# Batch   550: Loss per batch is 0.698793 and Accuracy is 0.750000
# Batch   600: Loss per batch is 0.908537 and Accuracy is 0.718750
# Batch   650: Loss per batch is 0.753719 and Accuracy is 0.796875
# Batch   700: Loss per batch is 0.722504 and Accuracy is 0.750000
# Batch   750: Loss per batch is 0.692064 and Accuracy is 0.796875
# For Iteration: Loss is 0.920248 and Accuracy is 0.674780
# ----Test: Epoch 2 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.59      0.84      0.69      1000
#   automobile       0.69      0.94      0.80      1000
#         bird       0.61      0.51      0.56      1000
#          cat       0.66      0.21      0.32      1000
#         deer       0.81      0.31      0.45      1000
#          dog       0.44      0.83      0.57      1000
#         frog       0.77      0.69      0.73      1000
#        horse       0.61      0.78      0.69      1000
#         ship       0.86      0.77      0.82      1000
#        truck       0.89      0.64      0.74      1000
#
#     accuracy                           0.65     10000
#    macro avg       0.69      0.65      0.64     10000
# weighted avg       0.69      0.65      0.64     10000
#
# Training: Epoch 3 ------------------
# Batch     0: Loss per batch is 0.985195 and Accuracy is 0.671875
# Batch    50: Loss per batch is 0.591876 and Accuracy is 0.796875
# Batch   100: Loss per batch is 0.649727 and Accuracy is 0.781250
# Batch   150: Loss per batch is 1.053665 and Accuracy is 0.609375
# Batch   200: Loss per batch is 0.920147 and Accuracy is 0.609375
# Batch   250: Loss per batch is 0.734298 and Accuracy is 0.750000
# Batch   300: Loss per batch is 0.677691 and Accuracy is 0.765625
# Batch   350: Loss per batch is 0.718144 and Accuracy is 0.750000
# Batch   400: Loss per batch is 0.681038 and Accuracy is 0.750000
# Batch   450: Loss per batch is 0.634424 and Accuracy is 0.750000
# Batch   500: Loss per batch is 0.716915 and Accuracy is 0.750000
# Batch   550: Loss per batch is 0.605765 and Accuracy is 0.812500
# Batch   600: Loss per batch is 0.881999 and Accuracy is 0.687500
# Batch   650: Loss per batch is 0.686491 and Accuracy is 0.781250
# Batch   700: Loss per batch is 0.749032 and Accuracy is 0.796875
# Batch   750: Loss per batch is 0.736894 and Accuracy is 0.687500
# For Iteration: Loss is 0.721319 and Accuracy is 0.748980
# ----Test: Epoch 3 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.66      0.76      0.71      1000
#   automobile       0.96      0.71      0.81      1000
#         bird       0.56      0.74      0.64      1000
#          cat       0.73      0.35      0.47      1000
#         deer       0.86      0.39      0.54      1000
#          dog       0.61      0.67      0.64      1000
#         frog       0.77      0.81      0.79      1000
#        horse       0.52      0.93      0.67      1000
#         ship       0.78      0.90      0.84      1000
#        truck       0.91      0.74      0.82      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.74      0.70      0.69     10000
# weighted avg       0.74      0.70      0.69     10000
#
# Training: Epoch 4 ------------------
# Batch     0: Loss per batch is 0.676297 and Accuracy is 0.765625
# Batch    50: Loss per batch is 0.626780 and Accuracy is 0.781250
# Batch   100: Loss per batch is 0.659379 and Accuracy is 0.765625
# Batch   150: Loss per batch is 0.555869 and Accuracy is 0.796875
# Batch   200: Loss per batch is 0.545471 and Accuracy is 0.781250
# Batch   250: Loss per batch is 0.482473 and Accuracy is 0.859375
# Batch   300: Loss per batch is 0.630628 and Accuracy is 0.734375
# Batch   350: Loss per batch is 0.611229 and Accuracy is 0.796875
# Batch   400: Loss per batch is 0.657465 and Accuracy is 0.765625
# Batch   450: Loss per batch is 0.661538 and Accuracy is 0.765625
# Batch   500: Loss per batch is 0.820830 and Accuracy is 0.734375
# Batch   550: Loss per batch is 0.593071 and Accuracy is 0.796875
# Batch   600: Loss per batch is 0.733768 and Accuracy is 0.734375
# Batch   650: Loss per batch is 0.442368 and Accuracy is 0.843750
# Batch   700: Loss per batch is 0.727905 and Accuracy is 0.734375
# Batch   750: Loss per batch is 0.583927 and Accuracy is 0.765625
# For Iteration: Loss is 0.593859 and Accuracy is 0.797080
# ----Test: Epoch 4 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.62      0.83      0.71      1000
#   automobile       0.50      0.98      0.66      1000
#         bird       0.65      0.66      0.65      1000
#          cat       0.64      0.56      0.60      1000
#         deer       0.84      0.60      0.70      1000
#          dog       0.80      0.60      0.68      1000
#         frog       0.77      0.81      0.79      1000
#        horse       0.86      0.72      0.78      1000
#         ship       0.74      0.92      0.82      1000
#        truck       0.96      0.22      0.36      1000
#
#     accuracy                           0.69     10000
#    macro avg       0.74      0.69      0.68     10000
# weighted avg       0.74      0.69      0.68     10000
#
# Training: Epoch 5 ------------------
# Batch     0: Loss per batch is 0.605659 and Accuracy is 0.796875
# Batch    50: Loss per batch is 0.324241 and Accuracy is 0.859375
# Batch   100: Loss per batch is 0.279869 and Accuracy is 0.937500
# Batch   150: Loss per batch is 0.563540 and Accuracy is 0.796875
# Batch   200: Loss per batch is 0.577175 and Accuracy is 0.781250
# Batch   250: Loss per batch is 0.425779 and Accuracy is 0.843750
# Batch   300: Loss per batch is 0.361449 and Accuracy is 0.890625
# Batch   350: Loss per batch is 0.503215 and Accuracy is 0.843750
# Batch   400: Loss per batch is 0.351057 and Accuracy is 0.828125
# Batch   450: Loss per batch is 0.571478 and Accuracy is 0.812500
# Batch   500: Loss per batch is 0.541640 and Accuracy is 0.796875
# Batch   550: Loss per batch is 0.637778 and Accuracy is 0.765625
# Batch   600: Loss per batch is 0.585185 and Accuracy is 0.812500
# Batch   650: Loss per batch is 0.426266 and Accuracy is 0.890625
# Batch   700: Loss per batch is 0.417449 and Accuracy is 0.890625
# Batch   750: Loss per batch is 0.650248 and Accuracy is 0.750000
# For Iteration: Loss is 0.497225 and Accuracy is 0.831220
# ----Test: Epoch 5 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.72      0.90      0.80      1000
#   automobile       0.83      0.95      0.88      1000
#         bird       0.61      0.77      0.68      1000
#          cat       0.63      0.69      0.66      1000
#         deer       0.82      0.73      0.78      1000
#          dog       0.83      0.60      0.70      1000
#         frog       0.88      0.76      0.82      1000
#        horse       0.77      0.87      0.82      1000
#         ship       0.96      0.75      0.84      1000
#        truck       0.95      0.83      0.89      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.80      0.78      0.79     10000
# weighted avg       0.80      0.78      0.79     10000
#
# Training: Epoch 6 ------------------
# Batch     0: Loss per batch is 0.389646 and Accuracy is 0.843750
# Batch    50: Loss per batch is 0.207736 and Accuracy is 0.906250
# Batch   100: Loss per batch is 0.411976 and Accuracy is 0.843750
# Batch   150: Loss per batch is 0.579750 and Accuracy is 0.750000
# Batch   200: Loss per batch is 0.502039 and Accuracy is 0.859375
# Batch   250: Loss per batch is 0.366980 and Accuracy is 0.890625
# Batch   300: Loss per batch is 0.482746 and Accuracy is 0.796875
# Batch   350: Loss per batch is 0.326003 and Accuracy is 0.875000
# Batch   400: Loss per batch is 0.683900 and Accuracy is 0.765625
# Batch   450: Loss per batch is 0.380938 and Accuracy is 0.843750
# Batch   500: Loss per batch is 0.452592 and Accuracy is 0.859375
# Batch   550: Loss per batch is 0.351240 and Accuracy is 0.843750
# Batch   600: Loss per batch is 0.376681 and Accuracy is 0.875000
# Batch   650: Loss per batch is 0.537174 and Accuracy is 0.828125
# Batch   700: Loss per batch is 0.350025 and Accuracy is 0.890625
# Batch   750: Loss per batch is 0.374450 and Accuracy is 0.843750
# For Iteration: Loss is 0.417972 and Accuracy is 0.857160
# ----Test: Epoch 6 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.80      0.83      1000
#   automobile       0.86      0.95      0.90      1000
#         bird       0.61      0.81      0.70      1000
#          cat       0.64      0.66      0.65      1000
#         deer       0.92      0.51      0.65      1000
#          dog       0.70      0.80      0.75      1000
#         frog       0.78      0.79      0.78      1000
#        horse       0.86      0.81      0.83      1000
#         ship       0.87      0.92      0.89      1000
#        truck       0.93      0.83      0.87      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# Training: Epoch 7 ------------------
# Batch     0: Loss per batch is 0.324757 and Accuracy is 0.890625
# Batch    50: Loss per batch is 0.385315 and Accuracy is 0.843750
# Batch   100: Loss per batch is 0.260113 and Accuracy is 0.906250
# Batch   150: Loss per batch is 0.409175 and Accuracy is 0.843750
# Batch   200: Loss per batch is 0.472605 and Accuracy is 0.812500
# Batch   250: Loss per batch is 0.289032 and Accuracy is 0.906250
# Batch   300: Loss per batch is 0.344448 and Accuracy is 0.875000
# Batch   350: Loss per batch is 0.609457 and Accuracy is 0.781250
# Batch   400: Loss per batch is 0.414289 and Accuracy is 0.859375
# Batch   450: Loss per batch is 0.326406 and Accuracy is 0.890625
# Batch   500: Loss per batch is 0.130638 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.323655 and Accuracy is 0.890625
# Batch   600: Loss per batch is 0.325189 and Accuracy is 0.859375
# Batch   650: Loss per batch is 0.230629 and Accuracy is 0.953125
# Batch   700: Loss per batch is 0.314923 and Accuracy is 0.921875
# Batch   750: Loss per batch is 0.385610 and Accuracy is 0.890625
# For Iteration: Loss is 0.346388 and Accuracy is 0.881720
# ----Test: Epoch 7 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.92      0.67      0.78      1000
#   automobile       0.94      0.87      0.90      1000
#         bird       0.51      0.91      0.66      1000
#          cat       0.72      0.45      0.55      1000
#         deer       0.91      0.59      0.71      1000
#          dog       0.59      0.83      0.69      1000
#         frog       0.89      0.77      0.82      1000
#        horse       0.90      0.73      0.81      1000
#         ship       0.95      0.80      0.87      1000
#        truck       0.70      0.96      0.81      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.80      0.76      0.76     10000
# weighted avg       0.80      0.76      0.76     10000
#
# Training: Epoch 8 ------------------
# Batch     0: Loss per batch is 0.304388 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.234141 and Accuracy is 0.906250
# Batch   100: Loss per batch is 0.313991 and Accuracy is 0.906250
# Batch   150: Loss per batch is 0.212130 and Accuracy is 0.937500
# Batch   200: Loss per batch is 0.284222 and Accuracy is 0.890625
# Batch   250: Loss per batch is 0.210136 and Accuracy is 0.921875
# Batch   300: Loss per batch is 0.367627 and Accuracy is 0.906250
# Batch   350: Loss per batch is 0.382526 and Accuracy is 0.796875
# Batch   400: Loss per batch is 0.194214 and Accuracy is 0.953125
# Batch   450: Loss per batch is 0.197617 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.428845 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.297785 and Accuracy is 0.906250
# Batch   600: Loss per batch is 0.308574 and Accuracy is 0.875000
# Batch   650: Loss per batch is 0.411921 and Accuracy is 0.843750
# Batch   700: Loss per batch is 0.453184 and Accuracy is 0.906250
# Batch   750: Loss per batch is 0.291165 and Accuracy is 0.890625
# For Iteration: Loss is 0.283662 and Accuracy is 0.905420
# ----Test: Epoch 8 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.83      0.83      1000
#   automobile       0.96      0.85      0.90      1000
#         bird       0.71      0.75      0.73      1000
#          cat       0.79      0.44      0.57      1000
#         deer       0.83      0.71      0.77      1000
#          dog       0.84      0.62      0.71      1000
#         frog       0.61      0.96      0.75      1000
#        horse       0.79      0.89      0.84      1000
#         ship       0.83      0.93      0.88      1000
#        truck       0.85      0.90      0.87      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.78     10000
# weighted avg       0.80      0.79      0.78     10000
#
# Training: Epoch 9 ------------------
# Batch     0: Loss per batch is 0.249945 and Accuracy is 0.921875
# Batch    50: Loss per batch is 0.240988 and Accuracy is 0.890625
# Batch   100: Loss per batch is 0.245471 and Accuracy is 0.921875
# Batch   150: Loss per batch is 0.309869 and Accuracy is 0.906250
# Batch   200: Loss per batch is 0.291833 and Accuracy is 0.875000
# Batch   250: Loss per batch is 0.210954 and Accuracy is 0.906250
# Batch   300: Loss per batch is 0.224203 and Accuracy is 0.937500
# Batch   350: Loss per batch is 0.126662 and Accuracy is 0.953125
# Batch   400: Loss per batch is 0.125959 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.147408 and Accuracy is 0.953125
# Batch   500: Loss per batch is 0.295691 and Accuracy is 0.859375
# Batch   550: Loss per batch is 0.151603 and Accuracy is 0.921875
# Batch   600: Loss per batch is 0.273877 and Accuracy is 0.875000
# Batch   650: Loss per batch is 0.127110 and Accuracy is 0.968750
# Batch   700: Loss per batch is 0.317483 and Accuracy is 0.843750
# Batch   750: Loss per batch is 0.210100 and Accuracy is 0.906250
# For Iteration: Loss is 0.221262 and Accuracy is 0.926320
# ----Test: Epoch 9 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.85      0.82      1000
#   automobile       0.99      0.68      0.81      1000
#         bird       0.94      0.37      0.53      1000
#          cat       0.58      0.81      0.67      1000
#         deer       0.63      0.88      0.73      1000
#          dog       0.86      0.59      0.70      1000
#         frog       0.84      0.80      0.82      1000
#        horse       0.70      0.90      0.79      1000
#         ship       0.97      0.80      0.88      1000
#        truck       0.73      0.94      0.82      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.80      0.76      0.76     10000
# weighted avg       0.80      0.76      0.76     10000
#
# Training: Epoch 10 ------------------
# Batch     0: Loss per batch is 0.138564 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.170268 and Accuracy is 0.953125
# Batch   100: Loss per batch is 0.123983 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.130978 and Accuracy is 0.953125
# Batch   200: Loss per batch is 0.283470 and Accuracy is 0.906250
# Batch   250: Loss per batch is 0.169144 and Accuracy is 0.937500
# Batch   300: Loss per batch is 0.187725 and Accuracy is 0.953125
# Batch   350: Loss per batch is 0.170355 and Accuracy is 0.921875
# Batch   400: Loss per batch is 0.250881 and Accuracy is 0.906250
# Batch   450: Loss per batch is 0.219116 and Accuracy is 0.937500
# Batch   500: Loss per batch is 0.199132 and Accuracy is 0.953125
# Batch   550: Loss per batch is 0.138639 and Accuracy is 0.953125
# Batch   600: Loss per batch is 0.180897 and Accuracy is 0.937500
# Batch   650: Loss per batch is 0.122933 and Accuracy is 0.953125
# Batch   700: Loss per batch is 0.184552 and Accuracy is 0.937500
# Batch   750: Loss per batch is 0.136565 and Accuracy is 0.953125
# For Iteration: Loss is 0.171409 and Accuracy is 0.943400
# ----Test: Epoch 10 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.91      0.84      1000
#   automobile       0.96      0.88      0.92      1000
#         bird       0.89      0.57      0.70      1000
#          cat       0.86      0.36      0.51      1000
#         deer       0.59      0.92      0.72      1000
#          dog       0.63      0.81      0.71      1000
#         frog       0.93      0.73      0.82      1000
#        horse       0.69      0.93      0.79      1000
#         ship       0.94      0.87      0.90      1000
#        truck       0.92      0.88      0.90      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.82      0.79      0.78     10000
# weighted avg       0.82      0.79      0.78     10000
#
# Training: Epoch 11 ------------------
# Batch     0: Loss per batch is 0.133177 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.189547 and Accuracy is 0.921875
# Batch   100: Loss per batch is 0.077349 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.133061 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.124126 and Accuracy is 0.937500
# Batch   250: Loss per batch is 0.071905 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.155358 and Accuracy is 0.968750
# Batch   350: Loss per batch is 0.079159 and Accuracy is 0.953125
# Batch   400: Loss per batch is 0.107481 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.123381 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.144374 and Accuracy is 0.953125
# Batch   550: Loss per batch is 0.278435 and Accuracy is 0.875000
# Batch   600: Loss per batch is 0.208517 and Accuracy is 0.921875
# Batch   650: Loss per batch is 0.129360 and Accuracy is 0.921875
# Batch   700: Loss per batch is 0.136550 and Accuracy is 0.937500
# Batch   750: Loss per batch is 0.242607 and Accuracy is 0.937500
# For Iteration: Loss is 0.128782 and Accuracy is 0.958140
# ----Test: Epoch 11 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.88      0.79      0.83      1000
#   automobile       0.90      0.94      0.92      1000
#         bird       0.64      0.82      0.72      1000
#          cat       0.68      0.62      0.65      1000
#         deer       0.84      0.66      0.74      1000
#          dog       0.73      0.76      0.74      1000
#         frog       0.96      0.57      0.71      1000
#        horse       0.67      0.94      0.78      1000
#         ship       0.89      0.91      0.90      1000
#        truck       0.89      0.91      0.90      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.79     10000
# weighted avg       0.81      0.79      0.79     10000
#
# Training: Epoch 12 ------------------
# Batch     0: Loss per batch is 0.092476 and Accuracy is 0.968750
# Batch    50: Loss per batch is 0.056325 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.077177 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.058387 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.060075 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.198282 and Accuracy is 0.921875
# Batch   300: Loss per batch is 0.112634 and Accuracy is 0.968750
# Batch   350: Loss per batch is 0.039989 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.090843 and Accuracy is 0.953125
# Batch   450: Loss per batch is 0.113454 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.067138 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.037731 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.149957 and Accuracy is 0.953125
# Batch   650: Loss per batch is 0.103153 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.135817 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.177862 and Accuracy is 0.906250
# For Iteration: Loss is 0.098771 and Accuracy is 0.968200
# ----Test: Epoch 12 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.81      0.82      1000
#   automobile       0.93      0.85      0.89      1000
#         bird       0.90      0.46      0.61      1000
#          cat       0.84      0.29      0.43      1000
#         deer       0.79      0.74      0.77      1000
#          dog       0.38      0.96      0.55      1000
#         frog       0.77      0.90      0.83      1000
#        horse       0.91      0.70      0.79      1000
#         ship       0.97      0.78      0.87      1000
#        truck       0.82      0.90      0.86      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.82      0.74      0.74     10000
# weighted avg       0.82      0.74      0.74     10000
#
# Training: Epoch 13 ------------------
# Batch     0: Loss per batch is 0.109764 and Accuracy is 0.968750
# Batch    50: Loss per batch is 0.092568 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.105241 and Accuracy is 0.953125
# Batch   150: Loss per batch is 0.036245 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.088847 and Accuracy is 0.968750
# Batch   250: Loss per batch is 0.026235 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.084635 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.048922 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.213813 and Accuracy is 0.890625
# Batch   450: Loss per batch is 0.028235 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.039676 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.140493 and Accuracy is 0.953125
# Batch   600: Loss per batch is 0.165991 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.089741 and Accuracy is 0.968750
# Batch   700: Loss per batch is 0.059249 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.134024 and Accuracy is 0.968750
# For Iteration: Loss is 0.081688 and Accuracy is 0.974860
# ----Test: Epoch 13 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.86      0.83      1000
#   automobile       0.97      0.85      0.91      1000
#         bird       0.69      0.77      0.73      1000
#          cat       0.57      0.76      0.65      1000
#         deer       0.89      0.63      0.74      1000
#          dog       0.70      0.80      0.75      1000
#         frog       0.97      0.67      0.79      1000
#        horse       0.83      0.84      0.84      1000
#         ship       0.84      0.94      0.89      1000
#        truck       0.93      0.87      0.90      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.82      0.80      0.80     10000
# weighted avg       0.82      0.80      0.80     10000
#
# Training: Epoch 14 ------------------
# Batch     0: Loss per batch is 0.148698 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.074936 and Accuracy is 0.953125
# Batch   100: Loss per batch is 0.082173 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.095155 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.080094 and Accuracy is 0.968750
# Batch   250: Loss per batch is 0.021306 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.045575 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.009664 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.046744 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.040309 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.049417 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.096877 and Accuracy is 0.968750
# Batch   600: Loss per batch is 0.019127 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.023384 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.178781 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.038315 and Accuracy is 1.000000
# For Iteration: Loss is 0.072448 and Accuracy is 0.977260
# ----Test: Epoch 14 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.79      0.79      1000
#   automobile       0.96      0.88      0.92      1000
#         bird       0.91      0.51      0.65      1000
#          cat       0.55      0.83      0.66      1000
#         deer       0.89      0.52      0.66      1000
#          dog       0.83      0.63      0.71      1000
#         frog       0.88      0.80      0.84      1000
#        horse       0.62      0.95      0.75      1000
#         ship       0.81      0.95      0.87      1000
#        truck       0.87      0.93      0.90      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.81      0.78      0.78     10000
# weighted avg       0.81      0.78      0.78     10000
#
# Training: Epoch 15 ------------------
# Batch     0: Loss per batch is 0.187514 and Accuracy is 0.921875
# Batch    50: Loss per batch is 0.060426 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.016798 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.063858 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.091989 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.020902 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.046550 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.048980 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.058723 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.023291 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.032105 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.048474 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.098973 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.169198 and Accuracy is 0.937500
# Batch   700: Loss per batch is 0.022734 and Accuracy is 1.000000
# Batch   750: Loss per batch is 0.100153 and Accuracy is 0.968750
# For Iteration: Loss is 0.063891 and Accuracy is 0.979240
# ----Test: Epoch 15 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.79      0.81      1000
#   automobile       0.96      0.87      0.91      1000
#         bird       0.85      0.66      0.75      1000
#          cat       0.55      0.83      0.66      1000
#         deer       0.72      0.86      0.78      1000
#          dog       0.90      0.50      0.65      1000
#         frog       0.84      0.84      0.84      1000
#        horse       0.93      0.77      0.84      1000
#         ship       0.71      0.96      0.82      1000
#        truck       0.93      0.87      0.90      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.82      0.80      0.80     10000
# weighted avg       0.82      0.80      0.80     10000
#
# Training: Epoch 16 ------------------
# Batch     0: Loss per batch is 0.029825 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.046939 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.020342 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.055959 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.020060 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.011383 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.064195 and Accuracy is 0.968750
# Batch   350: Loss per batch is 0.134970 and Accuracy is 0.953125
# Batch   400: Loss per batch is 0.018041 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.055390 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.020457 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.043154 and Accuracy is 0.968750
# Batch   600: Loss per batch is 0.075304 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.058833 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.039266 and Accuracy is 1.000000
# Batch   750: Loss per batch is 0.038909 and Accuracy is 0.984375
# For Iteration: Loss is 0.054002 and Accuracy is 0.983560
# ----Test: Epoch 16 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.76      0.80      1000
#   automobile       0.92      0.90      0.91      1000
#         bird       0.87      0.63      0.73      1000
#          cat       0.64      0.62      0.63      1000
#         deer       0.88      0.68      0.77      1000
#          dog       0.61      0.84      0.71      1000
#         frog       0.90      0.77      0.83      1000
#        horse       0.83      0.84      0.83      1000
#         ship       0.80      0.95      0.87      1000
#        truck       0.78      0.95      0.86      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.79     10000
# weighted avg       0.81      0.79      0.79     10000
#
# Training: Epoch 17 ------------------
# Batch     0: Loss per batch is 0.121885 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.101160 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.069651 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.012120 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.090615 and Accuracy is 0.968750
# Batch   250: Loss per batch is 0.027900 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.065033 and Accuracy is 0.968750
# Batch   350: Loss per batch is 0.016456 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.023769 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.058568 and Accuracy is 0.984375
# Batch   500: Loss per batch is 0.053656 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.017125 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.056048 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.067905 and Accuracy is 0.953125
# Batch   700: Loss per batch is 0.063445 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.135693 and Accuracy is 0.953125
# For Iteration: Loss is 0.064687 and Accuracy is 0.978840
# ----Test: Epoch 17 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.93      0.57      0.71      1000
#   automobile       0.98      0.54      0.70      1000
#         bird       0.85      0.63      0.72      1000
#          cat       0.85      0.48      0.62      1000
#         deer       0.51      0.94      0.67      1000
#          dog       0.84      0.66      0.74      1000
#         frog       0.84      0.85      0.85      1000
#        horse       0.89      0.69      0.77      1000
#         ship       0.85      0.88      0.87      1000
#        truck       0.47      0.98      0.64      1000
#
#     accuracy                           0.72     10000
#    macro avg       0.80      0.72      0.73     10000
# weighted avg       0.80      0.72      0.73     10000
#
# Training: Epoch 18 ------------------
# Batch     0: Loss per batch is 0.017928 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.119140 and Accuracy is 0.953125
# Batch   100: Loss per batch is 0.015229 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.055185 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.015748 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.041688 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.019962 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.034226 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.021464 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.038349 and Accuracy is 0.984375
# Batch   500: Loss per batch is 0.026519 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.016089 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.118534 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.056699 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.153812 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.120945 and Accuracy is 0.906250
# For Iteration: Loss is 0.049116 and Accuracy is 0.984300
# ----Test: Epoch 18 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.81      0.82      1000
#   automobile       0.91      0.92      0.91      1000
#         bird       0.90      0.59      0.71      1000
#          cat       0.72      0.62      0.67      1000
#         deer       0.79      0.82      0.81      1000
#          dog       0.65      0.83      0.73      1000
#         frog       0.81      0.90      0.86      1000
#        horse       0.93      0.75      0.83      1000
#         ship       0.83      0.94      0.88      1000
#        truck       0.83      0.94      0.88      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 19 ------------------
# Batch     0: Loss per batch is 0.012068 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.049115 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.095182 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.014709 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.021515 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.096608 and Accuracy is 0.968750
# Batch   300: Loss per batch is 0.053703 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.042405 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.058558 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.095773 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.053350 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.034466 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.052453 and Accuracy is 0.984375
# Batch   650: Loss per batch is 0.021809 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.054981 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.018801 and Accuracy is 1.000000
# For Iteration: Loss is 0.048156 and Accuracy is 0.984480
# ----Test: Epoch 19 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.91      0.73      0.81      1000
#   automobile       0.91      0.92      0.91      1000
#         bird       0.84      0.58      0.68      1000
#          cat       0.89      0.34      0.50      1000
#         deer       0.68      0.79      0.73      1000
#          dog       0.77      0.58      0.66      1000
#         frog       0.81      0.86      0.84      1000
#        horse       0.40      0.98      0.56      1000
#         ship       0.91      0.89      0.90      1000
#        truck       0.97      0.67      0.79      1000
#
#     accuracy                           0.73     10000
#    macro avg       0.81      0.73      0.74     10000
# weighted avg       0.81      0.73      0.74     10000
#
# Training: Epoch 20 ------------------
# Batch     0: Loss per batch is 0.058701 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.103206 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.049574 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.060112 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.004661 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.007807 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.013436 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.021282 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.086908 and Accuracy is 0.953125
# Batch   450: Loss per batch is 0.056734 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.069576 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.038097 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.108046 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.038168 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.088281 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.037853 and Accuracy is 0.984375
# For Iteration: Loss is 0.050733 and Accuracy is 0.982940
# ----Test: Epoch 20 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.80      0.80      1000
#   automobile       0.68      0.99      0.81      1000
#         bird       0.92      0.54      0.68      1000
#          cat       0.72      0.62      0.67      1000
#         deer       0.73      0.86      0.79      1000
#          dog       0.60      0.84      0.70      1000
#         frog       0.84      0.82      0.83      1000
#        horse       0.95      0.72      0.82      1000
#         ship       0.89      0.88      0.89      1000
#        truck       0.95      0.76      0.84      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.81      0.78      0.78     10000
# weighted avg       0.81      0.78      0.78     10000
#
# Training: Epoch 21 ------------------
# Batch     0: Loss per batch is 0.097894 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.068377 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.019138 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.091165 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.029437 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.050281 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.013699 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.010141 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.010400 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.013390 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.011735 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.012249 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.008445 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.017029 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.172172 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.034964 and Accuracy is 0.984375
# For Iteration: Loss is 0.040727 and Accuracy is 0.987100
# ----Test: Epoch 21 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.87      0.83      0.85      1000
#   automobile       0.95      0.89      0.92      1000
#         bird       0.87      0.58      0.70      1000
#          cat       0.54      0.68      0.60      1000
#         deer       0.91      0.46      0.61      1000
#          dog       0.47      0.85      0.60      1000
#         frog       0.97      0.48      0.65      1000
#        horse       0.65      0.90      0.76      1000
#         ship       0.93      0.88      0.90      1000
#        truck       0.89      0.92      0.90      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.80      0.75      0.75     10000
# weighted avg       0.80      0.75      0.75     10000
#
# Training: Epoch 22 ------------------
# Batch     0: Loss per batch is 0.099211 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.008295 and Accuracy is 1.000000
# Batch   100: Loss per batch is 0.027633 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.010133 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.046804 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.004232 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.047708 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.027834 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.031086 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.015218 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.007421 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.006591 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.049746 and Accuracy is 0.984375
# Batch   650: Loss per batch is 0.038544 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.083079 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.132718 and Accuracy is 0.953125
# For Iteration: Loss is 0.036065 and Accuracy is 0.988460
# ----Test: Epoch 22 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.77      0.87      0.82      1000
#   automobile       0.92      0.92      0.92      1000
#         bird       0.77      0.76      0.77      1000
#          cat       0.57      0.80      0.67      1000
#         deer       0.86      0.71      0.78      1000
#          dog       0.83      0.64      0.72      1000
#         frog       0.91      0.81      0.86      1000
#        horse       0.77      0.87      0.82      1000
#         ship       0.88      0.92      0.90      1000
#        truck       0.97      0.78      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 23 ------------------
# Batch     0: Loss per batch is 0.023732 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.033924 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.058152 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.037807 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.013783 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.093726 and Accuracy is 0.968750
# Batch   300: Loss per batch is 0.012302 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.043850 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.022246 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.007117 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.046752 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.004894 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.026547 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.013268 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.051875 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.018603 and Accuracy is 1.000000
# For Iteration: Loss is 0.045595 and Accuracy is 0.984840
# ----Test: Epoch 23 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.86      0.84      1000
#   automobile       0.85      0.95      0.90      1000
#         bird       0.66      0.83      0.73      1000
#          cat       0.70      0.64      0.67      1000
#         deer       0.86      0.73      0.79      1000
#          dog       0.71      0.77      0.74      1000
#         frog       0.82      0.85      0.83      1000
#        horse       0.91      0.77      0.84      1000
#         ship       0.96      0.82      0.88      1000
#        truck       0.90      0.87      0.88      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 24 ------------------
# Batch     0: Loss per batch is 0.024006 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.299831 and Accuracy is 0.921875
# Batch   100: Loss per batch is 0.042499 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.031282 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.020375 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.007535 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.059386 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.046447 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.062245 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.033652 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.043530 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.017415 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.010877 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.004150 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.034622 and Accuracy is 1.000000
# Batch   750: Loss per batch is 0.044426 and Accuracy is 0.984375
# For Iteration: Loss is 0.037659 and Accuracy is 0.988420
# ----Test: Epoch 24 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.94      0.74      1000
#   automobile       0.84      0.94      0.88      1000
#         bird       0.72      0.79      0.75      1000
#          cat       0.72      0.67      0.69      1000
#         deer       0.85      0.76      0.81      1000
#          dog       0.85      0.67      0.75      1000
#         frog       0.91      0.79      0.85      1000
#        horse       0.86      0.86      0.86      1000
#         ship       0.90      0.92      0.91      1000
#        truck       0.99      0.69      0.82      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.82      0.80      0.81     10000
# weighted avg       0.82      0.80      0.81     10000
#
# Training: Epoch 25 ------------------
# Batch     0: Loss per batch is 0.003058 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.028900 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.027768 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.018957 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.021323 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.004882 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.012380 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.020916 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.009122 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.013536 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.007015 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.038898 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.005979 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.037994 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.126071 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.003188 and Accuracy is 1.000000
# For Iteration: Loss is 0.035078 and Accuracy is 0.988800
# ----Test: Epoch 25 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.88      0.85      1000
#   automobile       0.87      0.96      0.91      1000
#         bird       0.77      0.76      0.77      1000
#          cat       0.76      0.66      0.70      1000
#         deer       0.70      0.89      0.78      1000
#          dog       0.79      0.72      0.76      1000
#         frog       0.83      0.89      0.86      1000
#        horse       0.93      0.77      0.84      1000
#         ship       0.95      0.87      0.91      1000
#        truck       0.91      0.88      0.89      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000
#
# Training: Epoch 26 ------------------
# Batch     0: Loss per batch is 0.023925 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.099121 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.061522 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.022876 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.014795 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.078833 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.035642 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.004233 and Accuracy is 1.000000
# Batch   400: Loss per batch is 0.013816 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.022322 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.031345 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.060993 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.007068 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.037143 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.042129 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.007326 and Accuracy is 1.000000
# For Iteration: Loss is 0.035957 and Accuracy is 0.987980
# ----Test: Epoch 26 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.75      0.91      0.82      1000
#   automobile       0.85      0.96      0.90      1000
#         bird       0.87      0.63      0.73      1000
#          cat       0.67      0.73      0.70      1000
#         deer       0.82      0.78      0.80      1000
#          dog       0.65      0.82      0.73      1000
#         frog       0.84      0.90      0.87      1000
#        horse       0.98      0.63      0.76      1000
#         ship       0.91      0.90      0.91      1000
#        truck       0.90      0.84      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 27 ------------------
# Batch     0: Loss per batch is 0.004987 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.019567 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.047279 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.065653 and Accuracy is 0.984375
# Batch   200: Loss per batch is 0.036308 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.015813 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.084072 and Accuracy is 0.953125
# Batch   350: Loss per batch is 0.068881 and Accuracy is 0.968750
# Batch   400: Loss per batch is 0.017483 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.037655 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.004825 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.026204 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.006995 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.080058 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.042317 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.027093 and Accuracy is 0.984375
# For Iteration: Loss is 0.029648 and Accuracy is 0.990260
# ----Test: Epoch 27 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.88      0.85      1000
#   automobile       0.94      0.90      0.92      1000
#         bird       0.88      0.64      0.74      1000
#          cat       0.69      0.71      0.70      1000
#         deer       0.63      0.93      0.75      1000
#          dog       0.88      0.64      0.74      1000
#         frog       0.90      0.85      0.87      1000
#        horse       0.80      0.85      0.83      1000
#         ship       0.93      0.91      0.92      1000
#        truck       0.88      0.93      0.90      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.84      0.82      0.82     10000
# weighted avg       0.84      0.82      0.82     10000
#
# Training: Epoch 28 ------------------
# Batch     0: Loss per batch is 0.053005 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.001926 and Accuracy is 1.000000
# Batch   100: Loss per batch is 0.001474 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.007748 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.004344 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.001979 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.013860 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.027522 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.024998 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.019703 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.038254 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.037719 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.173795 and Accuracy is 0.953125
# Batch   650: Loss per batch is 0.004004 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.037427 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.025802 and Accuracy is 0.984375
# For Iteration: Loss is 0.033044 and Accuracy is 0.989440
# ----Test: Epoch 28 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.73      0.91      0.81      1000
#   automobile       0.89      0.93      0.91      1000
#         bird       0.84      0.68      0.75      1000
#          cat       0.73      0.58      0.65      1000
#         deer       0.56      0.94      0.70      1000
#          dog       0.91      0.53      0.67      1000
#         frog       0.90      0.78      0.84      1000
#        horse       0.85      0.82      0.84      1000
#         ship       0.74      0.94      0.83      1000
#        truck       0.98      0.74      0.85      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.78     10000
# weighted avg       0.81      0.79      0.78     10000
#
# Training: Epoch 29 ------------------
# Batch     0: Loss per batch is 0.019479 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.045498 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.066183 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.073328 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.069792 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.042589 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.074059 and Accuracy is 0.953125
# Batch   350: Loss per batch is 0.029489 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.003479 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.016805 and Accuracy is 0.984375
# Batch   500: Loss per batch is 0.026897 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.016026 and Accuracy is 1.000000
# Batch   600: Loss per batch is 0.002310 and Accuracy is 1.000000
# Batch   650: Loss per batch is 0.015641 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.009603 and Accuracy is 1.000000
# Batch   750: Loss per batch is 0.009596 and Accuracy is 1.000000
# For Iteration: Loss is 0.032496 and Accuracy is 0.989460
# ----Test: Epoch 29 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.73      0.92      0.81      1000
#   automobile       0.87      0.95      0.91      1000
#         bird       0.83      0.70      0.76      1000
#          cat       0.64      0.78      0.70      1000
#         deer       0.78      0.85      0.81      1000
#          dog       0.84      0.69      0.76      1000
#         frog       0.84      0.89      0.87      1000
#        horse       0.94      0.75      0.83      1000
#         ship       0.90      0.93      0.91      1000
#        truck       0.98      0.76      0.86      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 30 ------------------
# Batch     0: Loss per batch is 0.005826 and Accuracy is 1.000000
# Batch    50: Loss per batch is 0.035229 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.021075 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.013877 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.012668 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.017984 and Accuracy is 1.000000
# Batch   300: Loss per batch is 0.002771 and Accuracy is 1.000000
# Batch   350: Loss per batch is 0.021177 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.033332 and Accuracy is 0.984375
# Batch   450: Loss per batch is 0.017479 and Accuracy is 0.984375
# Batch   500: Loss per batch is 0.004731 and Accuracy is 1.000000
# Batch   550: Loss per batch is 0.029871 and Accuracy is 0.984375
# Batch   600: Loss per batch is 0.046333 and Accuracy is 0.984375
# Batch   650: Loss per batch is 0.029155 and Accuracy is 1.000000
# Batch   700: Loss per batch is 0.028258 and Accuracy is 0.984375
# Batch   750: Loss per batch is 0.025834 and Accuracy is 0.984375
# For Iteration: Loss is 0.024838 and Accuracy is 0.992000
# ----Test: Epoch 30 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.83      0.85      1000
#   automobile       0.92      0.93      0.92      1000
#         bird       0.63      0.85      0.72      1000
#          cat       0.76      0.58      0.66      1000
#         deer       0.76      0.80      0.78      1000
#          dog       0.61      0.86      0.71      1000
#         frog       0.86      0.80      0.83      1000
#        horse       0.97      0.64      0.77      1000
#         ship       0.92      0.90      0.91      1000
#        truck       0.95      0.82      0.88      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.82      0.80      0.80     10000
# weighted avg       0.82      0.80      0.80     10000

# %%
torch.save(model, './cifar10_resnet18_nothing.pt')
