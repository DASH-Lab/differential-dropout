# %%
import torch
import torch.nn as nn  
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report
import ResNet as resnet
import DenseNet as densenet
import EfficientNet as efficientnet
import MobileNetV2 as mobilenet
import ViT as vit
import solver.solver as solver
import solver.solver_v2 as solver_v2
import solver.solver_v3 as solver_v3

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

n_epochs = 30
batch_size = 64
learning_rate = 1e-4
diff_drop = "v3"

model = resnet.resnet18(num_classes=10, diff_drop=diff_drop).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_path = "/media/data1/hyunjun/cifar-10/train/"
test_path = "/media/data1/hyunjun/cifar-10/test/"

# %%
trans = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.491, 0.482, 0.447), (0.247, 0.243, 0.262)),
])

trainset = torchvision.datasets.ImageFolder(root=train_path, transform=trans)
testset = torchvision.datasets.ImageFolder(root=test_path, transform=trans)

train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, drop_last=False, )
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=True, drop_last=False, )

classes = trainset.classes
print(classes)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def train_loop(dataloader, model, criterion, optimizer, epoch):
    size = len(dataloader.dataset)
    total_correct = 0
    total_loss = 0
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        model.train()
        correct = 0
        
        pred = None
        p = 0.0
        if diff_drop == "v3":
            pred, p = model(X.to(device), epoch)
        else:
            pred, p = model(X.to(device))
        
        loss = criterion(pred, y.to(device))
        correct += (torch.argmax(pred, dim=1) == y.to(device)).type(torch.float).sum().item()
        total_correct += correct
        
        model.train()
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        
        if diff_drop == "v1":
            solver.PseudoPruning(model.fc, p)
        elif diff_drop == "v2":
            solver_v2.PseudoPruning(model.fc, p)
        elif diff_drop == "v3":
            solver_v3.PseudoPruning(model.fc, p)
        
        optimizer.step()
        
        if (batch % 50 == 0):
            print(f"Batch {batch:>5d}: Loss per batch is {loss.item():>7.6f} and Accuracy is {correct / batch_size:>7.6f}")
    print(f"For Iteration: Loss is {(total_loss / (size // batch_size)):>7.6f} and Accuracy is {total_correct / size:>7.6f}")

# %%
def test_loop(dataloader, model, criterion):
    test_loss = 0
    correct = 0

    model.eval()
    
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for X, y in dataloader:
            pred, _ = model(X.to(device))
            test_loss += criterion(pred, y.to(device)).item()
            
            pred = torch.argmax(pred, dim=1)
            correct += (pred == y.to(device)).type(torch.float).sum().item()
            
            pred = pred.cpu().numpy()
            y = y.cpu().numpy()
            y_true.extend(y)
            y_pred.extend(pred)
    
    print(classification_report(y_true=y_true, y_pred=y_pred, target_names=classes))
    
    return correct / len(dataloader.dataset)

# %%
max = 0.0
for epoch in range(n_epochs):
    print(f"Training: Epoch {epoch + 1} ------------------")
    train_loop(train_loader, model, criterion, optimizer, epoch + 1)
    print(f"----Test: Epoch {epoch + 1} ------------------")
    temp = test_loop(test_loader, model, criterion)
    
    if temp > max:
        max = temp
        torch.save(model, './cifar10_resnet18_v3.pt')
# Out:
# Training: Epoch 1 ------------------
# Batch     0: Loss per batch is 2.344597 and Accuracy is 0.109375
# Batch    50: Loss per batch is 1.858081 and Accuracy is 0.265625
# Batch   100: Loss per batch is 1.746601 and Accuracy is 0.375000
# Batch   150: Loss per batch is 1.669308 and Accuracy is 0.359375
# Batch   200: Loss per batch is 1.379650 and Accuracy is 0.468750
# Batch   250: Loss per batch is 1.351484 and Accuracy is 0.500000
# Batch   300: Loss per batch is 1.442316 and Accuracy is 0.484375
# Batch   350: Loss per batch is 1.382575 and Accuracy is 0.468750
# Batch   400: Loss per batch is 1.273989 and Accuracy is 0.609375
# Batch   450: Loss per batch is 1.245557 and Accuracy is 0.484375
# Batch   500: Loss per batch is 1.517464 and Accuracy is 0.437500
# Batch   550: Loss per batch is 1.197252 and Accuracy is 0.562500
# Batch   600: Loss per batch is 1.194639 and Accuracy is 0.609375
# Batch   650: Loss per batch is 1.211939 and Accuracy is 0.562500
# Batch   700: Loss per batch is 1.130621 and Accuracy is 0.640625
# Batch   750: Loss per batch is 1.165935 and Accuracy is 0.546875
# For Iteration: Loss is 1.422031 and Accuracy is 0.485100
# ----Test: Epoch 1 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.54      0.73      0.62      1000
#   automobile       0.59      0.91      0.71      1000
#         bird       0.47      0.42      0.44      1000
#          cat       0.43      0.43      0.43      1000
#         deer       0.48      0.45      0.47      1000
#          dog       0.59      0.45      0.51      1000
#         frog       0.54      0.81      0.65      1000
#        horse       0.78      0.55      0.65      1000
#         ship       0.72      0.64      0.68      1000
#        truck       0.92      0.39      0.55      1000
#
#     accuracy                           0.58     10000
#    macro avg       0.61      0.58      0.57     10000
# weighted avg       0.61      0.58      0.57     10000
#
# Training: Epoch 2 ------------------
# Batch     0: Loss per batch is 1.525122 and Accuracy is 0.406250
# Batch    50: Loss per batch is 1.062368 and Accuracy is 0.671875
# Batch   100: Loss per batch is 1.262323 and Accuracy is 0.562500
# Batch   150: Loss per batch is 0.960501 and Accuracy is 0.703125
# Batch   200: Loss per batch is 1.157745 and Accuracy is 0.625000
# Batch   250: Loss per batch is 1.063906 and Accuracy is 0.640625
# Batch   300: Loss per batch is 1.339745 and Accuracy is 0.546875
# Batch   350: Loss per batch is 0.981690 and Accuracy is 0.656250
# Batch   400: Loss per batch is 1.159820 and Accuracy is 0.593750
# Batch   450: Loss per batch is 0.972216 and Accuracy is 0.640625
# Batch   500: Loss per batch is 1.046691 and Accuracy is 0.703125
# Batch   550: Loss per batch is 0.987119 and Accuracy is 0.671875
# Batch   600: Loss per batch is 1.067684 and Accuracy is 0.671875
# Batch   650: Loss per batch is 1.049956 and Accuracy is 0.687500
# Batch   700: Loss per batch is 0.969538 and Accuracy is 0.656250
# Batch   750: Loss per batch is 1.046033 and Accuracy is 0.593750
# For Iteration: Loss is 1.088152 and Accuracy is 0.621780
# ----Test: Epoch 2 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.81      0.69      1000
#   automobile       0.84      0.87      0.85      1000
#         bird       0.45      0.62      0.52      1000
#          cat       0.60      0.26      0.36      1000
#         deer       0.62      0.54      0.57      1000
#          dog       0.56      0.68      0.61      1000
#         frog       0.67      0.73      0.70      1000
#        horse       0.75      0.70      0.72      1000
#         ship       0.86      0.69      0.77      1000
#        truck       0.86      0.80      0.83      1000
#
#     accuracy                           0.67     10000
#    macro avg       0.68      0.67      0.66     10000
# weighted avg       0.68      0.67      0.66     10000
#
# Training: Epoch 3 ------------------
# Batch     0: Loss per batch is 0.779509 and Accuracy is 0.656250
# Batch    50: Loss per batch is 1.144725 and Accuracy is 0.578125
# Batch   100: Loss per batch is 0.972326 and Accuracy is 0.687500
# Batch   150: Loss per batch is 1.099494 and Accuracy is 0.656250
# Batch   200: Loss per batch is 0.779310 and Accuracy is 0.703125
# Batch   250: Loss per batch is 1.287189 and Accuracy is 0.546875
# Batch   300: Loss per batch is 1.177186 and Accuracy is 0.531250
# Batch   350: Loss per batch is 0.749393 and Accuracy is 0.796875
# Batch   400: Loss per batch is 1.034033 and Accuracy is 0.718750
# Batch   450: Loss per batch is 0.877999 and Accuracy is 0.734375
# Batch   500: Loss per batch is 0.982956 and Accuracy is 0.671875
# Batch   550: Loss per batch is 0.869603 and Accuracy is 0.703125
# Batch   600: Loss per batch is 0.846846 and Accuracy is 0.703125
# Batch   650: Loss per batch is 0.861212 and Accuracy is 0.687500
# Batch   700: Loss per batch is 0.699359 and Accuracy is 0.781250
# Batch   750: Loss per batch is 0.994440 and Accuracy is 0.625000
# For Iteration: Loss is 0.930817 and Accuracy is 0.682020
# ----Test: Epoch 3 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.67      0.73      1000
#   automobile       0.95      0.55      0.70      1000
#         bird       0.74      0.41      0.53      1000
#          cat       0.35      0.72      0.47      1000
#         deer       0.63      0.64      0.63      1000
#          dog       0.48      0.70      0.57      1000
#         frog       0.78      0.62      0.69      1000
#        horse       0.89      0.56      0.69      1000
#         ship       0.93      0.68      0.79      1000
#        truck       0.66      0.86      0.75      1000
#
#     accuracy                           0.64     10000
#    macro avg       0.72      0.64      0.65     10000
# weighted avg       0.72      0.64      0.65     10000
#
# Training: Epoch 4 ------------------
# Batch     0: Loss per batch is 1.040654 and Accuracy is 0.609375
# Batch    50: Loss per batch is 0.931657 and Accuracy is 0.625000
# Batch   100: Loss per batch is 0.969887 and Accuracy is 0.656250
# Batch   150: Loss per batch is 0.774723 and Accuracy is 0.703125
# Batch   200: Loss per batch is 0.797030 and Accuracy is 0.734375
# Batch   250: Loss per batch is 1.107378 and Accuracy is 0.656250
# Batch   300: Loss per batch is 0.825392 and Accuracy is 0.734375
# Batch   350: Loss per batch is 1.155300 and Accuracy is 0.593750
# Batch   400: Loss per batch is 0.809454 and Accuracy is 0.750000
# Batch   450: Loss per batch is 1.344907 and Accuracy is 0.578125
# Batch   500: Loss per batch is 0.979301 and Accuracy is 0.656250
# Batch   550: Loss per batch is 0.719162 and Accuracy is 0.796875
# Batch   600: Loss per batch is 0.784984 and Accuracy is 0.703125
# Batch   650: Loss per batch is 0.920947 and Accuracy is 0.687500
# Batch   700: Loss per batch is 0.984091 and Accuracy is 0.703125
# Batch   750: Loss per batch is 0.904348 and Accuracy is 0.687500
# For Iteration: Loss is 0.976429 and Accuracy is 0.675280
# ----Test: Epoch 4 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.49      0.61      1000
#   automobile       0.97      0.70      0.81      1000
#         bird       0.87      0.30      0.44      1000
#          cat       0.54      0.60      0.57      1000
#         deer       0.64      0.71      0.67      1000
#          dog       0.59      0.74      0.66      1000
#         frog       0.61      0.91      0.73      1000
#        horse       0.91      0.64      0.75      1000
#         ship       0.66      0.93      0.77      1000
#        truck       0.73      0.94      0.82      1000
#
#     accuracy                           0.69     10000
#    macro avg       0.73      0.69      0.68     10000
# weighted avg       0.73      0.69      0.68     10000
#
# Training: Epoch 5 ------------------
# Batch     0: Loss per batch is 0.755244 and Accuracy is 0.765625
# Batch    50: Loss per batch is 0.635661 and Accuracy is 0.796875
# Batch   100: Loss per batch is 0.806832 and Accuracy is 0.796875
# Batch   150: Loss per batch is 0.810391 and Accuracy is 0.765625
# Batch   200: Loss per batch is 0.778114 and Accuracy is 0.734375
# Batch   250: Loss per batch is 0.629105 and Accuracy is 0.765625
# Batch   300: Loss per batch is 0.675014 and Accuracy is 0.718750
# Batch   350: Loss per batch is 0.715506 and Accuracy is 0.750000
# Batch   400: Loss per batch is 0.718149 and Accuracy is 0.812500
# Batch   450: Loss per batch is 0.694236 and Accuracy is 0.781250
# Batch   500: Loss per batch is 0.856209 and Accuracy is 0.734375
# Batch   550: Loss per batch is 0.885956 and Accuracy is 0.703125
# Batch   600: Loss per batch is 0.853953 and Accuracy is 0.781250
# Batch   650: Loss per batch is 0.911872 and Accuracy is 0.765625
# Batch   700: Loss per batch is 0.579641 and Accuracy is 0.828125
# Batch   750: Loss per batch is 0.671239 and Accuracy is 0.750000
# For Iteration: Loss is 0.816884 and Accuracy is 0.731820
# ----Test: Epoch 5 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.69      0.85      0.76      1000
#   automobile       0.94      0.86      0.90      1000
#         bird       0.86      0.45      0.59      1000
#          cat       0.62      0.64      0.63      1000
#         deer       0.83      0.60      0.70      1000
#          dog       0.68      0.75      0.71      1000
#         frog       0.78      0.83      0.81      1000
#        horse       0.75      0.84      0.79      1000
#         ship       0.75      0.91      0.82      1000
#        truck       0.83      0.90      0.87      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.77      0.76      0.76     10000
# weighted avg       0.77      0.76      0.76     10000
#
# Training: Epoch 6 ------------------
# Batch     0: Loss per batch is 0.629902 and Accuracy is 0.765625
# Batch    50: Loss per batch is 0.850674 and Accuracy is 0.796875
# Batch   100: Loss per batch is 0.859464 and Accuracy is 0.718750
# Batch   150: Loss per batch is 0.838442 and Accuracy is 0.703125
# Batch   200: Loss per batch is 0.831142 and Accuracy is 0.750000
# Batch   250: Loss per batch is 0.763267 and Accuracy is 0.750000
# Batch   300: Loss per batch is 0.751176 and Accuracy is 0.781250
# Batch   350: Loss per batch is 0.888130 and Accuracy is 0.718750
# Batch   400: Loss per batch is 0.929906 and Accuracy is 0.671875
# Batch   450: Loss per batch is 0.633010 and Accuracy is 0.796875
# Batch   500: Loss per batch is 1.007916 and Accuracy is 0.718750
# Batch   550: Loss per batch is 0.698895 and Accuracy is 0.796875
# Batch   600: Loss per batch is 0.975810 and Accuracy is 0.703125
# Batch   650: Loss per batch is 0.727979 and Accuracy is 0.734375
# Batch   700: Loss per batch is 1.025877 and Accuracy is 0.703125
# Batch   750: Loss per batch is 0.629155 and Accuracy is 0.781250
# For Iteration: Loss is 0.799818 and Accuracy is 0.744000
# ----Test: Epoch 6 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.74      0.79      0.76      1000
#   automobile       0.89      0.91      0.90      1000
#         bird       0.61      0.69      0.65      1000
#          cat       0.51      0.71      0.59      1000
#         deer       0.82      0.59      0.69      1000
#          dog       0.90      0.48      0.62      1000
#         frog       0.85      0.78      0.81      1000
#        horse       0.79      0.80      0.80      1000
#         ship       0.82      0.90      0.86      1000
#        truck       0.84      0.90      0.87      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.78      0.76      0.76     10000
# weighted avg       0.78      0.76      0.76     10000
#
# Training: Epoch 7 ------------------
# Batch     0: Loss per batch is 1.203299 and Accuracy is 0.609375
# Batch    50: Loss per batch is 0.857553 and Accuracy is 0.671875
# Batch   100: Loss per batch is 1.065229 and Accuracy is 0.578125
# Batch   150: Loss per batch is 0.789875 and Accuracy is 0.703125
# Batch   200: Loss per batch is 0.901239 and Accuracy is 0.718750
# Batch   250: Loss per batch is 0.901733 and Accuracy is 0.718750
# Batch   300: Loss per batch is 1.006160 and Accuracy is 0.656250
# Batch   350: Loss per batch is 1.000514 and Accuracy is 0.656250
# Batch   400: Loss per batch is 0.699671 and Accuracy is 0.828125
# Batch   450: Loss per batch is 0.995586 and Accuracy is 0.593750
# Batch   500: Loss per batch is 1.076339 and Accuracy is 0.609375
# Batch   550: Loss per batch is 1.044653 and Accuracy is 0.625000
# Batch   600: Loss per batch is 0.654237 and Accuracy is 0.796875
# Batch   650: Loss per batch is 1.241913 and Accuracy is 0.625000
# Batch   700: Loss per batch is 0.979886 and Accuracy is 0.687500
# Batch   750: Loss per batch is 0.574334 and Accuracy is 0.812500
# For Iteration: Loss is 1.002215 and Accuracy is 0.656060
# ----Test: Epoch 7 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.82      0.82      1000
#   automobile       0.93      0.91      0.92      1000
#         bird       0.89      0.34      0.49      1000
#          cat       0.61      0.60      0.61      1000
#         deer       0.72      0.75      0.73      1000
#          dog       0.50      0.87      0.64      1000
#         frog       0.89      0.72      0.80      1000
#        horse       0.79      0.83      0.81      1000
#         ship       0.87      0.92      0.89      1000
#        truck       0.91      0.88      0.90      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.79      0.76      0.76     10000
# weighted avg       0.79      0.76      0.76     10000
#
# Training: Epoch 8 ------------------
# Batch     0: Loss per batch is 0.609913 and Accuracy is 0.875000
# Batch    50: Loss per batch is 0.687477 and Accuracy is 0.750000
# Batch   100: Loss per batch is 0.989183 and Accuracy is 0.703125
# Batch   150: Loss per batch is 0.677423 and Accuracy is 0.812500
# Batch   200: Loss per batch is 0.680907 and Accuracy is 0.765625
# Batch   250: Loss per batch is 0.756267 and Accuracy is 0.703125
# Batch   300: Loss per batch is 0.674676 and Accuracy is 0.765625
# Batch   350: Loss per batch is 0.619970 and Accuracy is 0.812500
# Batch   400: Loss per batch is 0.750868 and Accuracy is 0.765625
# Batch   450: Loss per batch is 0.832608 and Accuracy is 0.812500
# Batch   500: Loss per batch is 0.573283 and Accuracy is 0.828125
# Batch   550: Loss per batch is 0.417745 and Accuracy is 0.875000
# Batch   600: Loss per batch is 0.724154 and Accuracy is 0.812500
# Batch   650: Loss per batch is 0.525070 and Accuracy is 0.781250
# Batch   700: Loss per batch is 0.456074 and Accuracy is 0.843750
# Batch   750: Loss per batch is 0.706068 and Accuracy is 0.781250
# For Iteration: Loss is 0.676655 and Accuracy is 0.790720
# ----Test: Epoch 8 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.86      0.83      1000
#   automobile       0.96      0.86      0.91      1000
#         bird       0.74      0.62      0.67      1000
#          cat       0.85      0.34      0.49      1000
#         deer       0.87      0.64      0.74      1000
#          dog       0.51      0.89      0.65      1000
#         frog       0.81      0.84      0.83      1000
#        horse       0.72      0.88      0.79      1000
#         ship       0.88      0.91      0.89      1000
#        truck       0.87      0.90      0.88      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.80      0.77      0.77     10000
# weighted avg       0.80      0.77      0.77     10000
#
# Training: Epoch 9 ------------------
# Batch     0: Loss per batch is 1.084265 and Accuracy is 0.625000
# Batch    50: Loss per batch is 0.850378 and Accuracy is 0.718750
# Batch   100: Loss per batch is 1.125951 and Accuracy is 0.640625
# Batch   150: Loss per batch is 0.991400 and Accuracy is 0.625000
# Batch   200: Loss per batch is 0.868384 and Accuracy is 0.656250
# Batch   250: Loss per batch is 0.934216 and Accuracy is 0.625000
# Batch   300: Loss per batch is 0.878298 and Accuracy is 0.765625
# Batch   350: Loss per batch is 1.136908 and Accuracy is 0.640625
# Batch   400: Loss per batch is 0.770043 and Accuracy is 0.687500
# Batch   450: Loss per batch is 0.903337 and Accuracy is 0.703125
# Batch   500: Loss per batch is 0.976081 and Accuracy is 0.640625
# Batch   550: Loss per batch is 1.039794 and Accuracy is 0.734375
# Batch   600: Loss per batch is 1.047799 and Accuracy is 0.656250
# Batch   650: Loss per batch is 0.906078 and Accuracy is 0.703125
# Batch   700: Loss per batch is 1.094303 and Accuracy is 0.640625
# Batch   750: Loss per batch is 0.846977 and Accuracy is 0.718750
# For Iteration: Loss is 0.907851 and Accuracy is 0.689680
# ----Test: Epoch 9 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.88      0.72      0.80      1000
#   automobile       0.90      0.89      0.90      1000
#         bird       0.83      0.67      0.74      1000
#          cat       0.59      0.76      0.67      1000
#         deer       0.82      0.79      0.81      1000
#          dog       0.76      0.74      0.75      1000
#         frog       0.84      0.84      0.84      1000
#        horse       0.86      0.85      0.85      1000
#         ship       0.89      0.82      0.86      1000
#        truck       0.76      0.95      0.84      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.80      0.80     10000
#
# Training: Epoch 10 ------------------
# Batch     0: Loss per batch is 0.889470 and Accuracy is 0.656250
# Batch    50: Loss per batch is 0.996297 and Accuracy is 0.625000
# Batch   100: Loss per batch is 1.032183 and Accuracy is 0.609375
# Batch   150: Loss per batch is 0.942917 and Accuracy is 0.687500
# Batch   200: Loss per batch is 1.283401 and Accuracy is 0.515625
# Batch   250: Loss per batch is 1.173555 and Accuracy is 0.546875
# Batch   300: Loss per batch is 1.310958 and Accuracy is 0.515625
# Batch   350: Loss per batch is 1.032273 and Accuracy is 0.609375
# Batch   400: Loss per batch is 0.962254 and Accuracy is 0.640625
# Batch   450: Loss per batch is 0.952448 and Accuracy is 0.625000
# Batch   500: Loss per batch is 0.958655 and Accuracy is 0.625000
# Batch   550: Loss per batch is 1.266981 and Accuracy is 0.515625
# Batch   600: Loss per batch is 1.077282 and Accuracy is 0.578125
# Batch   650: Loss per batch is 1.085066 and Accuracy is 0.609375
# Batch   700: Loss per batch is 1.136389 and Accuracy is 0.546875
# Batch   750: Loss per batch is 1.050862 and Accuracy is 0.656250
# For Iteration: Loss is 1.085109 and Accuracy is 0.597940
# ----Test: Epoch 10 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.91      0.65      0.76      1000
#   automobile       0.90      0.94      0.92      1000
#         bird       0.75      0.75      0.75      1000
#          cat       0.61      0.78      0.69      1000
#         deer       0.75      0.85      0.80      1000
#          dog       0.85      0.66      0.74      1000
#         frog       0.91      0.81      0.86      1000
#        horse       0.91      0.81      0.86      1000
#         ship       0.77      0.95      0.85      1000
#        truck       0.88      0.91      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 11 ------------------
# Batch     0: Loss per batch is 0.666105 and Accuracy is 0.875000
# Batch    50: Loss per batch is 0.713029 and Accuracy is 0.765625
# Batch   100: Loss per batch is 0.511190 and Accuracy is 0.890625
# Batch   150: Loss per batch is 0.829869 and Accuracy is 0.765625
# Batch   200: Loss per batch is 0.527450 and Accuracy is 0.812500
# Batch   250: Loss per batch is 0.470974 and Accuracy is 0.843750
# Batch   300: Loss per batch is 0.487128 and Accuracy is 0.859375
# Batch   350: Loss per batch is 0.701001 and Accuracy is 0.859375
# Batch   400: Loss per batch is 0.448024 and Accuracy is 0.875000
# Batch   450: Loss per batch is 0.390218 and Accuracy is 0.890625
# Batch   500: Loss per batch is 0.672864 and Accuracy is 0.781250
# Batch   550: Loss per batch is 0.423944 and Accuracy is 0.875000
# Batch   600: Loss per batch is 0.615455 and Accuracy is 0.812500
# Batch   650: Loss per batch is 0.339502 and Accuracy is 0.921875
# Batch   700: Loss per batch is 0.530752 and Accuracy is 0.843750
# Batch   750: Loss per batch is 0.628413 and Accuracy is 0.765625
# For Iteration: Loss is 0.577002 and Accuracy is 0.830160
# ----Test: Epoch 11 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.70      0.91      0.79      1000
#   automobile       0.98      0.85      0.91      1000
#         bird       0.76      0.73      0.74      1000
#          cat       0.79      0.58      0.67      1000
#         deer       0.88      0.69      0.77      1000
#          dog       0.76      0.80      0.78      1000
#         frog       0.85      0.88      0.86      1000
#        horse       0.81      0.89      0.85      1000
#         ship       0.89      0.91      0.90      1000
#        truck       0.82      0.94      0.88      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000
#
# Training: Epoch 12 ------------------
# Batch     0: Loss per batch is 1.779505 and Accuracy is 0.468750
# Batch    50: Loss per batch is 1.334737 and Accuracy is 0.437500
# Batch   100: Loss per batch is 1.248878 and Accuracy is 0.562500
# Batch   150: Loss per batch is 1.021937 and Accuracy is 0.609375
# Batch   200: Loss per batch is 1.237865 and Accuracy is 0.468750
# Batch   250: Loss per batch is 1.330227 and Accuracy is 0.437500
# Batch   300: Loss per batch is 1.244931 and Accuracy is 0.546875
# Batch   350: Loss per batch is 1.372288 and Accuracy is 0.468750
# Batch   400: Loss per batch is 1.096271 and Accuracy is 0.546875
# Batch   450: Loss per batch is 1.257324 and Accuracy is 0.484375
# Batch   500: Loss per batch is 1.230273 and Accuracy is 0.453125
# Batch   550: Loss per batch is 1.289477 and Accuracy is 0.468750
# Batch   600: Loss per batch is 1.164019 and Accuracy is 0.546875
# Batch   650: Loss per batch is 1.064254 and Accuracy is 0.562500
# Batch   700: Loss per batch is 0.960201 and Accuracy is 0.656250
# Batch   750: Loss per batch is 1.110378 and Accuracy is 0.593750
# For Iteration: Loss is 1.210377 and Accuracy is 0.526900
# ----Test: Epoch 12 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.83      0.85      1000
#   automobile       0.98      0.84      0.90      1000
#         bird       0.85      0.58      0.69      1000
#          cat       0.81      0.58      0.68      1000
#         deer       0.62      0.93      0.74      1000
#          dog       0.66      0.84      0.74      1000
#         frog       0.79      0.88      0.84      1000
#        horse       0.96      0.72      0.82      1000
#         ship       0.93      0.89      0.91      1000
#        truck       0.81      0.95      0.88      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.83      0.80      0.80     10000
# weighted avg       0.83      0.80      0.80     10000
#
# Training: Epoch 13 ------------------
# Batch     0: Loss per batch is 1.023916 and Accuracy is 0.625000
# Batch    50: Loss per batch is 1.112016 and Accuracy is 0.562500
# Batch   100: Loss per batch is 1.262492 and Accuracy is 0.515625
# Batch   150: Loss per batch is 0.913667 and Accuracy is 0.671875
# Batch   200: Loss per batch is 0.910392 and Accuracy is 0.640625
# Batch   250: Loss per batch is 1.361082 and Accuracy is 0.453125
# Batch   300: Loss per batch is 0.930461 and Accuracy is 0.656250
# Batch   350: Loss per batch is 1.708874 and Accuracy is 0.359375
# Batch   400: Loss per batch is 1.138775 and Accuracy is 0.531250
# Batch   450: Loss per batch is 1.141506 and Accuracy is 0.578125
# Batch   500: Loss per batch is 1.280482 and Accuracy is 0.484375
# Batch   550: Loss per batch is 0.889370 and Accuracy is 0.671875
# Batch   600: Loss per batch is 1.208983 and Accuracy is 0.515625
# Batch   650: Loss per batch is 1.087791 and Accuracy is 0.578125
# Batch   700: Loss per batch is 1.047488 and Accuracy is 0.578125
# Batch   750: Loss per batch is 1.258498 and Accuracy is 0.562500
# For Iteration: Loss is 1.101847 and Accuracy is 0.574540
# ----Test: Epoch 13 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.86      0.83      1000
#   automobile       0.94      0.91      0.92      1000
#         bird       0.57      0.86      0.69      1000
#          cat       0.62      0.73      0.67      1000
#         deer       0.85      0.77      0.81      1000
#          dog       0.85      0.61      0.71      1000
#         frog       0.76      0.90      0.83      1000
#        horse       0.97      0.71      0.82      1000
#         ship       0.98      0.77      0.86      1000
#        truck       0.92      0.88      0.90      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.83      0.80      0.80     10000
# weighted avg       0.83      0.80      0.80     10000
#
# Training: Epoch 14 ------------------
# Batch     0: Loss per batch is 0.727892 and Accuracy is 0.843750
# Batch    50: Loss per batch is 0.600065 and Accuracy is 0.812500
# Batch   100: Loss per batch is 0.597024 and Accuracy is 0.781250
# Batch   150: Loss per batch is 0.649067 and Accuracy is 0.843750
# Batch   200: Loss per batch is 0.707657 and Accuracy is 0.734375
# Batch   250: Loss per batch is 0.525488 and Accuracy is 0.859375
# Batch   300: Loss per batch is 0.714539 and Accuracy is 0.750000
# Batch   350: Loss per batch is 0.457279 and Accuracy is 0.890625
# Batch   400: Loss per batch is 0.580311 and Accuracy is 0.812500
# Batch   450: Loss per batch is 0.497759 and Accuracy is 0.875000
# Batch   500: Loss per batch is 0.486163 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.729660 and Accuracy is 0.765625
# Batch   600: Loss per batch is 0.513171 and Accuracy is 0.828125
# Batch   650: Loss per batch is 0.585940 and Accuracy is 0.765625
# Batch   700: Loss per batch is 0.870367 and Accuracy is 0.765625
# Batch   750: Loss per batch is 0.726690 and Accuracy is 0.734375
# For Iteration: Loss is 0.645442 and Accuracy is 0.796820
# ----Test: Epoch 14 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.74      0.92      0.82      1000
#   automobile       0.98      0.82      0.89      1000
#         bird       0.87      0.58      0.70      1000
#          cat       0.84      0.43      0.57      1000
#         deer       0.70      0.86      0.77      1000
#          dog       0.52      0.93      0.67      1000
#         frog       0.95      0.70      0.81      1000
#        horse       0.93      0.79      0.85      1000
#         ship       0.91      0.92      0.92      1000
#        truck       0.83      0.95      0.89      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.83      0.79      0.79     10000
# weighted avg       0.83      0.79      0.79     10000
#
# Training: Epoch 15 ------------------
# Batch     0: Loss per batch is 1.885104 and Accuracy is 0.375000
# Batch    50: Loss per batch is 1.511474 and Accuracy is 0.375000
# Batch   100: Loss per batch is 1.521905 and Accuracy is 0.375000
# Batch   150: Loss per batch is 1.133600 and Accuracy is 0.484375
# Batch   200: Loss per batch is 1.800894 and Accuracy is 0.375000
# Batch   250: Loss per batch is 1.497015 and Accuracy is 0.343750
# Batch   300: Loss per batch is 1.424005 and Accuracy is 0.359375
# Batch   350: Loss per batch is 1.615972 and Accuracy is 0.343750
# Batch   400: Loss per batch is 1.628312 and Accuracy is 0.312500
# Batch   450: Loss per batch is 1.740838 and Accuracy is 0.359375
# Batch   500: Loss per batch is 1.591379 and Accuracy is 0.281250
# Batch   550: Loss per batch is 1.507416 and Accuracy is 0.328125
# Batch   600: Loss per batch is 1.392866 and Accuracy is 0.406250
# Batch   650: Loss per batch is 1.617054 and Accuracy is 0.328125
# Batch   700: Loss per batch is 1.898749 and Accuracy is 0.281250
# Batch   750: Loss per batch is 1.586941 and Accuracy is 0.296875
# For Iteration: Loss is 1.519444 and Accuracy is 0.376220
# ----Test: Epoch 15 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.86      0.84      1000
#   automobile       0.97      0.88      0.92      1000
#         bird       0.67      0.82      0.74      1000
#          cat       0.81      0.61      0.69      1000
#         deer       0.78      0.80      0.79      1000
#          dog       0.85      0.66      0.75      1000
#         frog       0.87      0.85      0.86      1000
#        horse       0.73      0.92      0.82      1000
#         ship       0.88      0.92      0.90      1000
#        truck       0.90      0.90      0.90      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 16 ------------------
# Batch     0: Loss per batch is 0.886721 and Accuracy is 0.734375
# Batch    50: Loss per batch is 0.869794 and Accuracy is 0.687500
# Batch   100: Loss per batch is 0.779894 and Accuracy is 0.734375
# Batch   150: Loss per batch is 0.979748 and Accuracy is 0.562500
# Batch   200: Loss per batch is 1.017265 and Accuracy is 0.625000
# Batch   250: Loss per batch is 1.150505 and Accuracy is 0.562500
# Batch   300: Loss per batch is 0.927147 and Accuracy is 0.593750
# Batch   350: Loss per batch is 1.004153 and Accuracy is 0.593750
# Batch   400: Loss per batch is 0.819832 and Accuracy is 0.640625
# Batch   450: Loss per batch is 0.975535 and Accuracy is 0.578125
# Batch   500: Loss per batch is 0.718430 and Accuracy is 0.718750
# Batch   550: Loss per batch is 1.044520 and Accuracy is 0.593750
# Batch   600: Loss per batch is 1.130631 and Accuracy is 0.562500
# Batch   650: Loss per batch is 0.853509 and Accuracy is 0.671875
# Batch   700: Loss per batch is 0.914927 and Accuracy is 0.546875
# Batch   750: Loss per batch is 0.959339 and Accuracy is 0.656250
# For Iteration: Loss is 0.979739 and Accuracy is 0.621740
# ----Test: Epoch 16 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.88      0.84      0.86      1000
#   automobile       0.93      0.94      0.94      1000
#         bird       0.77      0.74      0.76      1000
#          cat       0.79      0.69      0.74      1000
#         deer       0.75      0.88      0.81      1000
#          dog       0.83      0.72      0.77      1000
#         frog       0.78      0.93      0.85      1000
#        horse       0.89      0.83      0.86      1000
#         ship       0.92      0.91      0.91      1000
#        truck       0.90      0.92      0.91      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
# Training: Epoch 17 ------------------
# Batch     0: Loss per batch is 1.020658 and Accuracy is 0.656250
# Batch    50: Loss per batch is 0.809075 and Accuracy is 0.703125
# Batch   100: Loss per batch is 0.797694 and Accuracy is 0.703125
# Batch   150: Loss per batch is 0.689511 and Accuracy is 0.687500
# Batch   200: Loss per batch is 0.958080 and Accuracy is 0.656250
# Batch   250: Loss per batch is 0.977756 and Accuracy is 0.593750
# Batch   300: Loss per batch is 0.860914 and Accuracy is 0.671875
# Batch   350: Loss per batch is 0.978869 and Accuracy is 0.593750
# Batch   400: Loss per batch is 0.902701 and Accuracy is 0.656250
# Batch   450: Loss per batch is 0.766603 and Accuracy is 0.609375
# Batch   500: Loss per batch is 1.007919 and Accuracy is 0.578125
# Batch   550: Loss per batch is 1.003539 and Accuracy is 0.609375
# Batch   600: Loss per batch is 0.815262 and Accuracy is 0.656250
# Batch   650: Loss per batch is 0.781638 and Accuracy is 0.734375
# Batch   700: Loss per batch is 0.969707 and Accuracy is 0.578125
# Batch   750: Loss per batch is 0.953996 and Accuracy is 0.578125
# For Iteration: Loss is 0.986078 and Accuracy is 0.611740
# ----Test: Epoch 17 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.81      0.91      0.85      1000
#   automobile       0.97      0.84      0.90      1000
#         bird       0.76      0.77      0.76      1000
#          cat       0.78      0.67      0.72      1000
#         deer       0.86      0.80      0.83      1000
#          dog       0.81      0.75      0.78      1000
#         frog       0.84      0.90      0.87      1000
#        horse       0.87      0.89      0.88      1000
#         ship       0.93      0.89      0.91      1000
#        truck       0.79      0.97      0.87      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
# Training: Epoch 18 ------------------
# Batch     0: Loss per batch is 1.595733 and Accuracy is 0.375000
# Batch    50: Loss per batch is 1.720526 and Accuracy is 0.250000
# Batch   100: Loss per batch is 2.228133 and Accuracy is 0.265625
# Batch   150: Loss per batch is 1.683631 and Accuracy is 0.281250
# Batch   200: Loss per batch is 1.700401 and Accuracy is 0.265625
# Batch   250: Loss per batch is 1.658254 and Accuracy is 0.250000
# Batch   300: Loss per batch is 1.649699 and Accuracy is 0.328125
# Batch   350: Loss per batch is 1.675935 and Accuracy is 0.250000
# Batch   400: Loss per batch is 1.756660 and Accuracy is 0.218750
# Batch   450: Loss per batch is 1.731479 and Accuracy is 0.250000
# Batch   500: Loss per batch is 1.773198 and Accuracy is 0.312500
# Batch   550: Loss per batch is 1.630556 and Accuracy is 0.390625
# Batch   600: Loss per batch is 1.851866 and Accuracy is 0.234375
# Batch   650: Loss per batch is 1.671685 and Accuracy is 0.281250
# Batch   700: Loss per batch is 1.955487 and Accuracy is 0.234375
# Batch   750: Loss per batch is 1.488795 and Accuracy is 0.375000
# For Iteration: Loss is 1.693211 and Accuracy is 0.297100
# ----Test: Epoch 18 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.79      0.81      1000
#   automobile       0.97      0.76      0.85      1000
#         bird       0.84      0.61      0.71      1000
#          cat       0.65      0.70      0.67      1000
#         deer       0.73      0.84      0.78      1000
#          dog       0.72      0.77      0.74      1000
#         frog       0.90      0.79      0.85      1000
#        horse       0.91      0.78      0.84      1000
#         ship       0.85      0.93      0.89      1000
#        truck       0.68      0.97      0.80      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.79     10000
# weighted avg       0.81      0.79      0.79     10000
#
# Training: Epoch 19 ------------------
# Batch     0: Loss per batch is 1.000094 and Accuracy is 0.656250
# Batch    50: Loss per batch is 0.806562 and Accuracy is 0.781250
# Batch   100: Loss per batch is 0.642603 and Accuracy is 0.781250
# Batch   150: Loss per batch is 0.780413 and Accuracy is 0.687500
# Batch   200: Loss per batch is 0.611570 and Accuracy is 0.703125
# Batch   250: Loss per batch is 0.674596 and Accuracy is 0.734375
# Batch   300: Loss per batch is 0.769127 and Accuracy is 0.718750
# Batch   350: Loss per batch is 0.942978 and Accuracy is 0.640625
# Batch   400: Loss per batch is 0.700685 and Accuracy is 0.781250
# Batch   450: Loss per batch is 0.759090 and Accuracy is 0.703125
# Batch   500: Loss per batch is 0.673244 and Accuracy is 0.718750
# Batch   550: Loss per batch is 0.760591 and Accuracy is 0.734375
# Batch   600: Loss per batch is 0.756712 and Accuracy is 0.718750
# Batch   650: Loss per batch is 0.625482 and Accuracy is 0.812500
# Batch   700: Loss per batch is 0.693850 and Accuracy is 0.750000
# Batch   750: Loss per batch is 0.571393 and Accuracy is 0.828125
# For Iteration: Loss is 0.765573 and Accuracy is 0.727700
# ----Test: Epoch 19 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.86      0.86      1000
#   automobile       0.84      0.98      0.91      1000
#         bird       0.82      0.76      0.79      1000
#          cat       0.78      0.70      0.73      1000
#         deer       0.79      0.87      0.83      1000
#          dog       0.78      0.80      0.79      1000
#         frog       0.81      0.93      0.87      1000
#        horse       0.95      0.82      0.88      1000
#         ship       0.90      0.92      0.91      1000
#        truck       0.97      0.82      0.89      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000
#
# Training: Epoch 20 ------------------
# Batch     0: Loss per batch is 1.690008 and Accuracy is 0.343750
# Batch    50: Loss per batch is 1.681061 and Accuracy is 0.296875
# Batch   100: Loss per batch is 1.499351 and Accuracy is 0.406250
# Batch   150: Loss per batch is 1.690475 and Accuracy is 0.281250
# Batch   200: Loss per batch is 1.295293 and Accuracy is 0.468750
# Batch   250: Loss per batch is 1.537442 and Accuracy is 0.281250
# Batch   300: Loss per batch is 1.359690 and Accuracy is 0.421875
# Batch   350: Loss per batch is 1.608672 and Accuracy is 0.312500
# Batch   400: Loss per batch is 1.359738 and Accuracy is 0.406250
# Batch   450: Loss per batch is 1.542989 and Accuracy is 0.312500
# Batch   500: Loss per batch is 1.467048 and Accuracy is 0.453125
# Batch   550: Loss per batch is 1.412394 and Accuracy is 0.375000
# Batch   600: Loss per batch is 1.563628 and Accuracy is 0.312500
# Batch   650: Loss per batch is 1.536863 and Accuracy is 0.328125
# Batch   700: Loss per batch is 1.205039 and Accuracy is 0.515625
# Batch   750: Loss per batch is 1.319726 and Accuracy is 0.453125
# For Iteration: Loss is 1.476781 and Accuracy is 0.372600
# ----Test: Epoch 20 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.72      0.94      0.81      1000
#   automobile       0.94      0.93      0.93      1000
#         bird       0.76      0.75      0.75      1000
#          cat       0.72      0.68      0.70      1000
#         deer       0.85      0.80      0.82      1000
#          dog       0.83      0.71      0.77      1000
#         frog       0.83      0.91      0.87      1000
#        horse       0.86      0.89      0.88      1000
#         ship       0.92      0.88      0.90      1000
#        truck       0.94      0.87      0.90      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Training: Epoch 21 ------------------
# Batch     0: Loss per batch is 1.669962 and Accuracy is 0.312500
# Batch    50: Loss per batch is 1.778438 and Accuracy is 0.234375
# Batch   100: Loss per batch is 1.576678 and Accuracy is 0.312500
# Batch   150: Loss per batch is 1.635870 and Accuracy is 0.296875
# Batch   200: Loss per batch is 1.750711 and Accuracy is 0.234375
# Batch   250: Loss per batch is 1.615034 and Accuracy is 0.296875
# Batch   300: Loss per batch is 1.888714 and Accuracy is 0.250000
# Batch   350: Loss per batch is 1.697954 and Accuracy is 0.250000
# Batch   400: Loss per batch is 1.476196 and Accuracy is 0.359375
# Batch   450: Loss per batch is 1.810311 and Accuracy is 0.281250
# Batch   500: Loss per batch is 1.625871 and Accuracy is 0.343750
# Batch   550: Loss per batch is 1.915135 and Accuracy is 0.218750
# Batch   600: Loss per batch is 1.799351 and Accuracy is 0.312500
# Batch   650: Loss per batch is 1.645197 and Accuracy is 0.296875
# Batch   700: Loss per batch is 1.924798 and Accuracy is 0.218750
# Batch   750: Loss per batch is 1.687251 and Accuracy is 0.203125
# For Iteration: Loss is 1.738992 and Accuracy is 0.271920
# ----Test: Epoch 21 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.81      0.84      1000
#   automobile       0.88      0.95      0.91      1000
#         bird       0.70      0.80      0.75      1000
#          cat       0.65      0.78      0.71      1000
#         deer       0.81      0.80      0.81      1000
#          dog       0.86      0.61      0.71      1000
#         frog       0.81      0.92      0.86      1000
#        horse       0.91      0.81      0.85      1000
#         ship       0.84      0.93      0.88      1000
#        truck       0.98      0.77      0.86      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 22 ------------------
# Batch     0: Loss per batch is 0.723316 and Accuracy is 0.875000
# Batch    50: Loss per batch is 0.782482 and Accuracy is 0.781250
# Batch   100: Loss per batch is 0.392884 and Accuracy is 0.921875
# Batch   150: Loss per batch is 0.693905 and Accuracy is 0.765625
# Batch   200: Loss per batch is 0.555537 and Accuracy is 0.875000
# Batch   250: Loss per batch is 0.552460 and Accuracy is 0.750000
# Batch   300: Loss per batch is 0.627949 and Accuracy is 0.781250
# Batch   350: Loss per batch is 0.744742 and Accuracy is 0.750000
# Batch   400: Loss per batch is 0.535984 and Accuracy is 0.859375
# Batch   450: Loss per batch is 0.522249 and Accuracy is 0.812500
# Batch   500: Loss per batch is 0.763694 and Accuracy is 0.750000
# Batch   550: Loss per batch is 0.657809 and Accuracy is 0.781250
# Batch   600: Loss per batch is 0.751666 and Accuracy is 0.718750
# Batch   650: Loss per batch is 0.761402 and Accuracy is 0.750000
# Batch   700: Loss per batch is 0.556761 and Accuracy is 0.812500
# Batch   750: Loss per batch is 0.523063 and Accuracy is 0.765625
# For Iteration: Loss is 0.615532 and Accuracy is 0.798300
# ----Test: Epoch 22 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.87      0.86      0.86      1000
#   automobile       0.96      0.91      0.93      1000
#         bird       0.67      0.85      0.75      1000
#          cat       0.84      0.56      0.67      1000
#         deer       0.78      0.86      0.82      1000
#          dog       0.92      0.62      0.74      1000
#         frog       0.82      0.92      0.86      1000
#        horse       0.79      0.91      0.84      1000
#         ship       0.89      0.94      0.91      1000
#        truck       0.92      0.91      0.91      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Training: Epoch 23 ------------------
# Batch     0: Loss per batch is 2.423325 and Accuracy is 0.234375
# Batch    50: Loss per batch is 1.820355 and Accuracy is 0.281250
# Batch   100: Loss per batch is 1.820505 and Accuracy is 0.265625
# Batch   150: Loss per batch is 1.883083 and Accuracy is 0.250000
# Batch   200: Loss per batch is 1.847656 and Accuracy is 0.140625
# Batch   250: Loss per batch is 1.840010 and Accuracy is 0.250000
# Batch   300: Loss per batch is 1.839782 and Accuracy is 0.312500
# Batch   350: Loss per batch is 1.771194 and Accuracy is 0.296875
# Batch   400: Loss per batch is 1.799793 and Accuracy is 0.203125
# Batch   450: Loss per batch is 1.923885 and Accuracy is 0.250000
# Batch   500: Loss per batch is 1.813955 and Accuracy is 0.203125
# Batch   550: Loss per batch is 1.641732 and Accuracy is 0.312500
# Batch   600: Loss per batch is 1.792952 and Accuracy is 0.250000
# Batch   650: Loss per batch is 1.746962 and Accuracy is 0.312500
# Batch   700: Loss per batch is 1.733749 and Accuracy is 0.265625
# Batch   750: Loss per batch is 1.853706 and Accuracy is 0.187500
# For Iteration: Loss is 1.828385 and Accuracy is 0.251340
# ----Test: Epoch 23 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.73      0.91      0.81      1000
#   automobile       0.90      0.92      0.91      1000
#         bird       0.72      0.72      0.72      1000
#          cat       0.75      0.65      0.70      1000
#         deer       0.89      0.72      0.80      1000
#          dog       0.79      0.75      0.77      1000
#         frog       0.84      0.89      0.87      1000
#        horse       0.87      0.86      0.87      1000
#         ship       0.82      0.95      0.88      1000
#        truck       0.95      0.85      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 24 ------------------
# Batch     0: Loss per batch is 1.393838 and Accuracy is 0.421875
# Batch    50: Loss per batch is 1.655837 and Accuracy is 0.343750
# Batch   100: Loss per batch is 1.625829 and Accuracy is 0.281250
# Batch   150: Loss per batch is 1.673025 and Accuracy is 0.250000
# Batch   200: Loss per batch is 1.494010 and Accuracy is 0.390625
# Batch   250: Loss per batch is 1.626070 and Accuracy is 0.312500
# Batch   300: Loss per batch is 1.777627 and Accuracy is 0.312500
# Batch   350: Loss per batch is 1.663566 and Accuracy is 0.250000
# Batch   400: Loss per batch is 1.753006 and Accuracy is 0.203125
# Batch   450: Loss per batch is 1.648986 and Accuracy is 0.296875
# Batch   500: Loss per batch is 1.726309 and Accuracy is 0.250000
# Batch   550: Loss per batch is 1.575962 and Accuracy is 0.343750
# Batch   600: Loss per batch is 1.521066 and Accuracy is 0.328125
# Batch   650: Loss per batch is 1.549288 and Accuracy is 0.375000
# Batch   700: Loss per batch is 1.741014 and Accuracy is 0.234375
# Batch   750: Loss per batch is 1.807904 and Accuracy is 0.234375
# For Iteration: Loss is 1.657075 and Accuracy is 0.290880
# ----Test: Epoch 24 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.84      0.85      1000
#   automobile       0.96      0.91      0.94      1000
#         bird       0.82      0.70      0.75      1000
#          cat       0.68      0.73      0.71      1000
#         deer       0.83      0.86      0.85      1000
#          dog       0.72      0.81      0.76      1000
#         frog       0.83      0.91      0.87      1000
#        horse       0.93      0.83      0.88      1000
#         ship       0.92      0.91      0.91      1000
#        truck       0.92      0.92      0.92      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.85      0.84      0.84     10000
# weighted avg       0.85      0.84      0.84     10000
#
# Training: Epoch 25 ------------------
# Batch     0: Loss per batch is 0.931325 and Accuracy is 0.640625
# Batch    50: Loss per batch is 1.128050 and Accuracy is 0.593750
# Batch   100: Loss per batch is 1.043554 and Accuracy is 0.640625
# Batch   150: Loss per batch is 0.817027 and Accuracy is 0.703125
# Batch   200: Loss per batch is 0.597946 and Accuracy is 0.796875
# Batch   250: Loss per batch is 0.918642 and Accuracy is 0.640625
# Batch   300: Loss per batch is 0.917910 and Accuracy is 0.625000
# Batch   350: Loss per batch is 0.855895 and Accuracy is 0.687500
# Batch   400: Loss per batch is 0.862909 and Accuracy is 0.640625
# Batch   450: Loss per batch is 0.646125 and Accuracy is 0.734375
# Batch   500: Loss per batch is 0.890210 and Accuracy is 0.671875
# Batch   550: Loss per batch is 0.833076 and Accuracy is 0.656250
# Batch   600: Loss per batch is 1.051425 and Accuracy is 0.625000
# Batch   650: Loss per batch is 0.920275 and Accuracy is 0.703125
# Batch   700: Loss per batch is 0.744497 and Accuracy is 0.750000
# Batch   750: Loss per batch is 0.875541 and Accuracy is 0.609375
# For Iteration: Loss is 0.879850 and Accuracy is 0.656580
# ----Test: Epoch 25 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.75      0.89      0.82      1000
#   automobile       0.93      0.91      0.92      1000
#         bird       0.82      0.71      0.76      1000
#          cat       0.78      0.60      0.68      1000
#         deer       0.90      0.72      0.80      1000
#          dog       0.68      0.85      0.76      1000
#         frog       0.89      0.85      0.87      1000
#        horse       0.82      0.91      0.86      1000
#         ship       0.93      0.86      0.90      1000
#        truck       0.81      0.95      0.87      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 26 ------------------
# Batch     0: Loss per batch is 2.604690 and Accuracy is 0.156250
# Batch    50: Loss per batch is 2.292314 and Accuracy is 0.140625
# Batch   100: Loss per batch is 2.104542 and Accuracy is 0.203125
# Batch   150: Loss per batch is 2.172710 and Accuracy is 0.203125
# Batch   200: Loss per batch is 2.066417 and Accuracy is 0.156250
# Batch   250: Loss per batch is 1.989986 and Accuracy is 0.156250
# Batch   300: Loss per batch is 2.045566 and Accuracy is 0.203125
# Batch   350: Loss per batch is 1.993616 and Accuracy is 0.203125
# Batch   400: Loss per batch is 2.000478 and Accuracy is 0.156250
# Batch   450: Loss per batch is 2.054492 and Accuracy is 0.203125
# Batch   500: Loss per batch is 1.787043 and Accuracy is 0.296875
# Batch   550: Loss per batch is 1.808247 and Accuracy is 0.265625
# Batch   600: Loss per batch is 2.007582 and Accuracy is 0.203125
# Batch   650: Loss per batch is 2.001625 and Accuracy is 0.140625
# Batch   700: Loss per batch is 1.876174 and Accuracy is 0.203125
# Batch   750: Loss per batch is 2.026814 and Accuracy is 0.109375
# For Iteration: Loss is 2.038444 and Accuracy is 0.191920
# ----Test: Epoch 26 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.70      0.89      0.78      1000
#   automobile       0.92      0.92      0.92      1000
#         bird       0.83      0.70      0.76      1000
#          cat       0.68      0.72      0.70      1000
#         deer       0.83      0.82      0.83      1000
#          dog       0.74      0.75      0.74      1000
#         frog       0.88      0.86      0.87      1000
#        horse       0.87      0.85      0.86      1000
#         ship       0.89      0.87      0.88      1000
#        truck       0.96      0.84      0.90      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 27 ------------------
# Batch     0: Loss per batch is 1.493437 and Accuracy is 0.390625
# Batch    50: Loss per batch is 1.545079 and Accuracy is 0.312500
# Batch   100: Loss per batch is 1.519553 and Accuracy is 0.359375
# Batch   150: Loss per batch is 1.717054 and Accuracy is 0.218750
# Batch   200: Loss per batch is 1.350522 and Accuracy is 0.437500
# Batch   250: Loss per batch is 1.320405 and Accuracy is 0.468750
# Batch   300: Loss per batch is 1.744244 and Accuracy is 0.265625
# Batch   350: Loss per batch is 1.471191 and Accuracy is 0.406250
# Batch   400: Loss per batch is 1.473460 and Accuracy is 0.312500
# Batch   450: Loss per batch is 1.341814 and Accuracy is 0.421875
# Batch   500: Loss per batch is 1.473870 and Accuracy is 0.328125
# Batch   550: Loss per batch is 1.578286 and Accuracy is 0.312500
# Batch   600: Loss per batch is 1.711003 and Accuracy is 0.296875
# Batch   650: Loss per batch is 1.646299 and Accuracy is 0.296875
# Batch   700: Loss per batch is 1.490192 and Accuracy is 0.328125
# Batch   750: Loss per batch is 1.322016 and Accuracy is 0.406250
# For Iteration: Loss is 1.481705 and Accuracy is 0.363380
# ----Test: Epoch 27 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.91      0.80      0.85      1000
#   automobile       0.89      0.96      0.93      1000
#         bird       0.83      0.78      0.80      1000
#          cat       0.70      0.78      0.73      1000
#         deer       0.79      0.88      0.83      1000
#          dog       0.84      0.74      0.79      1000
#         frog       0.85      0.92      0.88      1000
#        horse       0.94      0.83      0.88      1000
#         ship       0.89      0.93      0.91      1000
#        truck       0.92      0.90      0.91      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.86      0.85      0.85     10000
# weighted avg       0.86      0.85      0.85     10000
#
# Training: Epoch 28 ------------------
# Batch     0: Loss per batch is 1.416823 and Accuracy is 0.312500
# Batch    50: Loss per batch is 1.237455 and Accuracy is 0.390625
# Batch   100: Loss per batch is 1.139909 and Accuracy is 0.515625
# Batch   150: Loss per batch is 1.244436 and Accuracy is 0.531250
# Batch   200: Loss per batch is 1.628510 and Accuracy is 0.281250
# Batch   250: Loss per batch is 1.448995 and Accuracy is 0.296875
# Batch   300: Loss per batch is 1.576928 and Accuracy is 0.390625
# Batch   350: Loss per batch is 1.280833 and Accuracy is 0.437500
# Batch   400: Loss per batch is 1.402165 and Accuracy is 0.375000
# Batch   450: Loss per batch is 1.390525 and Accuracy is 0.406250
# Batch   500: Loss per batch is 1.403498 and Accuracy is 0.343750
# Batch   550: Loss per batch is 1.344440 and Accuracy is 0.359375
# Batch   600: Loss per batch is 1.515301 and Accuracy is 0.359375
# Batch   650: Loss per batch is 1.545790 and Accuracy is 0.328125
# Batch   700: Loss per batch is 1.450014 and Accuracy is 0.359375
# Batch   750: Loss per batch is 1.390990 and Accuracy is 0.421875
# For Iteration: Loss is 1.424859 and Accuracy is 0.377380
# ----Test: Epoch 28 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.83      0.88      0.86      1000
#   automobile       0.91      0.94      0.93      1000
#         bird       0.71      0.83      0.76      1000
#          cat       0.70      0.72      0.71      1000
#         deer       0.83      0.83      0.83      1000
#          dog       0.85      0.66      0.75      1000
#         frog       0.87      0.89      0.88      1000
#        horse       0.84      0.88      0.86      1000
#         ship       0.91      0.91      0.91      1000
#        truck       0.97      0.82      0.89      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
# Training: Epoch 29 ------------------
# Batch     0: Loss per batch is 2.132483 and Accuracy is 0.234375
# Batch    50: Loss per batch is 2.094432 and Accuracy is 0.218750
# Batch   100: Loss per batch is 2.180336 and Accuracy is 0.093750
# Batch   150: Loss per batch is 2.289326 and Accuracy is 0.156250
# Batch   200: Loss per batch is 1.974892 and Accuracy is 0.140625
# Batch   250: Loss per batch is 1.943375 and Accuracy is 0.203125
# Batch   300: Loss per batch is 2.012899 and Accuracy is 0.187500
# Batch   350: Loss per batch is 2.071214 and Accuracy is 0.093750
# Batch   400: Loss per batch is 2.010754 and Accuracy is 0.218750
# Batch   450: Loss per batch is 1.807960 and Accuracy is 0.250000
# Batch   500: Loss per batch is 2.061712 and Accuracy is 0.171875
# Batch   550: Loss per batch is 1.964115 and Accuracy is 0.171875
# Batch   600: Loss per batch is 2.058835 and Accuracy is 0.125000
# Batch   650: Loss per batch is 1.881260 and Accuracy is 0.203125
# Batch   700: Loss per batch is 2.080616 and Accuracy is 0.265625
# Batch   750: Loss per batch is 2.094751 and Accuracy is 0.109375
# For Iteration: Loss is 2.033409 and Accuracy is 0.173440
# ----Test: Epoch 29 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.82      0.82      1000
#   automobile       0.90      0.92      0.91      1000
#         bird       0.67      0.76      0.71      1000
#          cat       0.66      0.68      0.67      1000
#         deer       0.81      0.79      0.80      1000
#          dog       0.83      0.65      0.73      1000
#         frog       0.78      0.91      0.84      1000
#        horse       0.88      0.81      0.84      1000
#         ship       0.86      0.92      0.89      1000
#        truck       0.94      0.85      0.90      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 30 ------------------
# Batch     0: Loss per batch is 1.359277 and Accuracy is 0.531250
# Batch    50: Loss per batch is 1.318874 and Accuracy is 0.453125
# Batch   100: Loss per batch is 1.107966 and Accuracy is 0.562500
# Batch   150: Loss per batch is 1.116666 and Accuracy is 0.531250
# Batch   200: Loss per batch is 1.188875 and Accuracy is 0.500000
# Batch   250: Loss per batch is 1.156230 and Accuracy is 0.578125
# Batch   300: Loss per batch is 0.921238 and Accuracy is 0.687500
# Batch   350: Loss per batch is 1.295689 and Accuracy is 0.421875
# Batch   400: Loss per batch is 1.190382 and Accuracy is 0.515625
# Batch   450: Loss per batch is 1.050687 and Accuracy is 0.562500
# Batch   500: Loss per batch is 1.213501 and Accuracy is 0.468750
# Batch   550: Loss per batch is 0.906911 and Accuracy is 0.625000
# Batch   600: Loss per batch is 0.842099 and Accuracy is 0.593750
# Batch   650: Loss per batch is 1.225490 and Accuracy is 0.390625
# Batch   700: Loss per batch is 1.280391 and Accuracy is 0.468750
# Batch   750: Loss per batch is 1.239930 and Accuracy is 0.453125
# For Iteration: Loss is 1.113003 and Accuracy is 0.532440
# ----Test: Epoch 30 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.87      0.87      0.87      1000
#   automobile       0.92      0.96      0.94      1000
#         bird       0.77      0.80      0.78      1000
#          cat       0.75      0.70      0.73      1000
#         deer       0.86      0.81      0.83      1000
#          dog       0.83      0.75      0.79      1000
#         frog       0.84      0.92      0.88      1000
#        horse       0.87      0.91      0.89      1000
#         ship       0.91      0.94      0.92      1000
#        truck       0.94      0.89      0.92      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.85      0.86      0.85     10000
# weighted avg       0.85      0.86      0.85     10000

# %%
torch.save(model, './cifar10_resnet18_v3.pt')
