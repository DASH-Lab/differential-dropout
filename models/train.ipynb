# %%
import torch
import torch.nn as nn  
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report
import ResNet as resnet
import DenseNet as densenet
import EfficientNet as efficientnet
import MobileNetV2 as mobilenet
import ViT as vit
import solver.solver as solver
import solver.solver_v2 as solver_v2
import solver.solver_v3 as solver_v3

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

n_epochs = 30
batch_size = 64
learning_rate = 1e-4
diff_drop = "v3"

model = resnet.resnet50(num_classes=10, diff_drop=diff_drop).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_path = "/media/data1/hyunjun/cifar-10/train/"
test_path = "/media/data1/hyunjun/cifar-10/test/"

# %%
trans = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.491, 0.482, 0.447), (0.247, 0.243, 0.262)),
])

trainset = torchvision.datasets.ImageFolder(root=train_path, transform=trans)
testset = torchvision.datasets.ImageFolder(root=test_path, transform=trans)

train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, drop_last=False, )
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=True, drop_last=False, )

classes = trainset.classes
print(classes)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def train_loop(dataloader, model, criterion, optimizer, epoch):
    size = len(dataloader.dataset)
    total_correct = 0
    total_loss = 0
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        model.train()
        correct = 0
        
        pred = None
        if diff_drop == "v3":
            pred = model(X.to(device), epoch)
        else:
            pred = model(X.to(device))
        
        loss = criterion(pred, y.to(device))
        correct += (torch.argmax(pred, dim=1) == y.to(device)).type(torch.float).sum().item()
        total_correct += correct
        
        model.train()
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        
        if diff_drop == "v1":
            solver.PseudoPruning(model.fc, X)
        elif diff_drop == "v2":
            solver_v2.PseudoPruning(model.fc, X)
        elif diff_drop == "v3":
            solver_v3.PseudoPruning(model.fc, X, epoch=epoch)
        
        optimizer.step()
        
        if (batch % 50 == 0):
            print(f"Batch {batch:>5d}: Loss per batch is {loss.item():>7.6f} and Accuracy is {correct / batch_size:>7.6f}")
    print(f"For Iteration: Loss is {(total_loss / (size // batch_size)):>7.6f} and Accuracy is {total_correct / size:>7.6f}")

# %%
def test_loop(dataloader, model, criterion):
    test_loss = 0
    correct = 0

    model.eval()
    
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(device))
            test_loss += criterion(pred, y.to(device)).item()
            
            pred = torch.argmax(pred, dim=1)
            correct += (pred == y.to(device)).type(torch.float).sum().item()
            
            pred = pred.cpu().numpy()
            y = y.cpu().numpy()
            y_true.extend(y)
            y_pred.extend(pred)
    
    print(classification_report(y_true=y_true, y_pred=y_pred, target_names=classes))
    
    return correct / len(dataloader.dataset)

# %%
max = 0.0
for epoch in range(n_epochs):
    print(f"Training: Epoch {epoch + 1} ------------------")
    train_loop(train_loader, model, criterion, optimizer, epoch + 1)
    print(f"----Test: Epoch {epoch + 1} ------------------")
    temp = test_loop(test_loader, model, criterion)
    
    if temp > max:
        max = temp
        torch.save(model, './cifar10_resnet50_v3.pt')
# Out:
# Training: Epoch 1 ------------------
# Batch     0: Loss per batch is 2.431921 and Accuracy is 0.140625
# Batch    50: Loss per batch is 1.982957 and Accuracy is 0.203125
# Batch   100: Loss per batch is 1.944069 and Accuracy is 0.203125
# Batch   150: Loss per batch is 1.914991 and Accuracy is 0.312500
# Batch   200: Loss per batch is 1.959573 and Accuracy is 0.281250
# Batch   250: Loss per batch is 1.747820 and Accuracy is 0.375000
# Batch   300: Loss per batch is 1.326401 and Accuracy is 0.468750
# Batch   350: Loss per batch is 1.682947 and Accuracy is 0.328125
# Batch   400: Loss per batch is 1.480607 and Accuracy is 0.468750
# Batch   450: Loss per batch is 1.467528 and Accuracy is 0.484375
# Batch   500: Loss per batch is 1.310195 and Accuracy is 0.468750
# Batch   550: Loss per batch is 1.621402 and Accuracy is 0.390625
# Batch   600: Loss per batch is 1.589342 and Accuracy is 0.437500
# Batch   650: Loss per batch is 1.485595 and Accuracy is 0.468750
# Batch   700: Loss per batch is 1.381975 and Accuracy is 0.453125
# Batch   750: Loss per batch is 1.417104 and Accuracy is 0.578125
# For Iteration: Loss is 1.624995 and Accuracy is 0.396800
# ----Test: Epoch 1 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.57      0.58      1000
#   automobile       0.77      0.47      0.58      1000
#         bird       0.45      0.27      0.34      1000
#          cat       0.36      0.35      0.35      1000
#         deer       0.47      0.33      0.39      1000
#          dog       0.44      0.57      0.49      1000
#         frog       0.45      0.74      0.56      1000
#        horse       0.56      0.65      0.60      1000
#         ship       0.56      0.74      0.64      1000
#        truck       0.69      0.51      0.58      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.53      0.52      0.51     10000
# weighted avg       0.53      0.52      0.51     10000
#
# Training: Epoch 2 ------------------
# Batch     0: Loss per batch is 1.297096 and Accuracy is 0.609375
# Batch    50: Loss per batch is 1.567134 and Accuracy is 0.390625
# Batch   100: Loss per batch is 1.468116 and Accuracy is 0.468750
# Batch   150: Loss per batch is 1.308527 and Accuracy is 0.500000
# Batch   200: Loss per batch is 1.379244 and Accuracy is 0.484375
# Batch   250: Loss per batch is 1.253843 and Accuracy is 0.437500
# Batch   300: Loss per batch is 1.250423 and Accuracy is 0.593750
# Batch   350: Loss per batch is 1.243802 and Accuracy is 0.578125
# Batch   400: Loss per batch is 1.339936 and Accuracy is 0.593750
# Batch   450: Loss per batch is 1.159073 and Accuracy is 0.562500
# Batch   500: Loss per batch is 1.029733 and Accuracy is 0.671875
# Batch   550: Loss per batch is 1.048687 and Accuracy is 0.640625
# Batch   600: Loss per batch is 0.834473 and Accuracy is 0.750000
# Batch   650: Loss per batch is 0.988599 and Accuracy is 0.640625
# Batch   700: Loss per batch is 1.335708 and Accuracy is 0.437500
# Batch   750: Loss per batch is 1.073037 and Accuracy is 0.656250
# For Iteration: Loss is 1.255569 and Accuracy is 0.548680
# ----Test: Epoch 2 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.67      0.69      0.68      1000
#   automobile       0.83      0.79      0.81      1000
#         bird       0.59      0.38      0.46      1000
#          cat       0.51      0.24      0.33      1000
#         deer       0.64      0.39      0.48      1000
#          dog       0.43      0.78      0.56      1000
#         frog       0.57      0.83      0.68      1000
#        horse       0.68      0.68      0.68      1000
#         ship       0.77      0.80      0.78      1000
#        truck       0.78      0.76      0.77      1000
#
#     accuracy                           0.63     10000
#    macro avg       0.65      0.63      0.62     10000
# weighted avg       0.65      0.63      0.62     10000
#
# Training: Epoch 3 ------------------
# Batch     0: Loss per batch is 1.278147 and Accuracy is 0.578125
# Batch    50: Loss per batch is 0.729536 and Accuracy is 0.734375
# Batch   100: Loss per batch is 0.932322 and Accuracy is 0.640625
# Batch   150: Loss per batch is 1.379600 and Accuracy is 0.515625
# Batch   200: Loss per batch is 1.143546 and Accuracy is 0.531250
# Batch   250: Loss per batch is 1.105008 and Accuracy is 0.609375
# Batch   300: Loss per batch is 1.151896 and Accuracy is 0.593750
# Batch   350: Loss per batch is 1.183579 and Accuracy is 0.625000
# Batch   400: Loss per batch is 1.186461 and Accuracy is 0.640625
# Batch   450: Loss per batch is 1.135929 and Accuracy is 0.656250
# Batch   500: Loss per batch is 0.899165 and Accuracy is 0.734375
# Batch   550: Loss per batch is 0.929601 and Accuracy is 0.656250
# Batch   600: Loss per batch is 1.133516 and Accuracy is 0.703125
# Batch   650: Loss per batch is 0.994941 and Accuracy is 0.671875
# Batch   700: Loss per batch is 1.175041 and Accuracy is 0.609375
# Batch   750: Loss per batch is 0.923519 and Accuracy is 0.703125
# For Iteration: Loss is 1.010809 and Accuracy is 0.646180
# ----Test: Epoch 3 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.63      0.81      0.71      1000
#   automobile       0.78      0.89      0.83      1000
#         bird       0.48      0.63      0.55      1000
#          cat       0.53      0.46      0.49      1000
#         deer       0.63      0.60      0.62      1000
#          dog       0.65      0.54      0.59      1000
#         frog       0.68      0.79      0.73      1000
#        horse       0.78      0.65      0.71      1000
#         ship       0.88      0.78      0.83      1000
#        truck       0.93      0.66      0.77      1000
#
#     accuracy                           0.68     10000
#    macro avg       0.70      0.68      0.68     10000
# weighted avg       0.70      0.68      0.68     10000
#
# Training: Epoch 4 ------------------
# Batch     0: Loss per batch is 0.784932 and Accuracy is 0.687500
# Batch    50: Loss per batch is 0.952041 and Accuracy is 0.640625
# Batch   100: Loss per batch is 1.072821 and Accuracy is 0.640625
# Batch   150: Loss per batch is 0.987275 and Accuracy is 0.687500
# Batch   200: Loss per batch is 1.104594 and Accuracy is 0.609375
# Batch   250: Loss per batch is 0.773219 and Accuracy is 0.703125
# Batch   300: Loss per batch is 0.975599 and Accuracy is 0.578125
# Batch   350: Loss per batch is 1.167696 and Accuracy is 0.625000
# Batch   400: Loss per batch is 1.010929 and Accuracy is 0.671875
# Batch   450: Loss per batch is 0.831191 and Accuracy is 0.765625
# Batch   500: Loss per batch is 0.771287 and Accuracy is 0.734375
# Batch   550: Loss per batch is 1.112956 and Accuracy is 0.593750
# Batch   600: Loss per batch is 1.105343 and Accuracy is 0.687500
# Batch   650: Loss per batch is 1.085116 and Accuracy is 0.593750
# Batch   700: Loss per batch is 0.687285 and Accuracy is 0.796875
# Batch   750: Loss per batch is 1.107559 and Accuracy is 0.609375
# For Iteration: Loss is 0.944386 and Accuracy is 0.676640
# ----Test: Epoch 4 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.72      0.75      1000
#   automobile       0.93      0.82      0.87      1000
#         bird       0.73      0.52      0.61      1000
#          cat       0.57      0.54      0.56      1000
#         deer       0.61      0.75      0.67      1000
#          dog       0.60      0.74      0.66      1000
#         frog       0.86      0.70      0.77      1000
#        horse       0.75      0.79      0.77      1000
#         ship       0.76      0.91      0.83      1000
#        truck       0.86      0.87      0.86      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.75      0.74      0.74     10000
# weighted avg       0.75      0.74      0.74     10000
#
# Training: Epoch 5 ------------------
# Batch     0: Loss per batch is 0.536251 and Accuracy is 0.828125
# Batch    50: Loss per batch is 0.821903 and Accuracy is 0.750000
# Batch   100: Loss per batch is 0.778379 and Accuracy is 0.671875
# Batch   150: Loss per batch is 0.666963 and Accuracy is 0.750000
# Batch   200: Loss per batch is 0.787859 and Accuracy is 0.703125
# Batch   250: Loss per batch is 1.146946 and Accuracy is 0.640625
# Batch   300: Loss per batch is 0.640486 and Accuracy is 0.812500
# Batch   350: Loss per batch is 0.686828 and Accuracy is 0.765625
# Batch   400: Loss per batch is 0.644121 and Accuracy is 0.750000
# Batch   450: Loss per batch is 0.881255 and Accuracy is 0.718750
# Batch   500: Loss per batch is 0.691498 and Accuracy is 0.750000
# Batch   550: Loss per batch is 0.556051 and Accuracy is 0.843750
# Batch   600: Loss per batch is 0.801683 and Accuracy is 0.765625
# Batch   650: Loss per batch is 0.858539 and Accuracy is 0.734375
# Batch   700: Loss per batch is 0.757664 and Accuracy is 0.765625
# Batch   750: Loss per batch is 0.537917 and Accuracy is 0.781250
# For Iteration: Loss is 0.760881 and Accuracy is 0.740380
# ----Test: Epoch 5 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.75      0.77      1000
#   automobile       0.87      0.92      0.89      1000
#         bird       0.58      0.75      0.65      1000
#          cat       0.59      0.65      0.62      1000
#         deer       0.78      0.66      0.72      1000
#          dog       0.71      0.67      0.69      1000
#         frog       0.74      0.86      0.80      1000
#        horse       0.94      0.57      0.71      1000
#         ship       0.84      0.88      0.86      1000
#        truck       0.86      0.85      0.86      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.77      0.76      0.76     10000
# weighted avg       0.77      0.76      0.76     10000
#
# Training: Epoch 6 ------------------
# Batch     0: Loss per batch is 0.678432 and Accuracy is 0.765625
# Batch    50: Loss per batch is 0.903300 and Accuracy is 0.703125
# Batch   100: Loss per batch is 0.611062 and Accuracy is 0.796875
# Batch   150: Loss per batch is 0.628492 and Accuracy is 0.796875
# Batch   200: Loss per batch is 0.573918 and Accuracy is 0.812500
# Batch   250: Loss per batch is 0.731222 and Accuracy is 0.765625
# Batch   300: Loss per batch is 0.581235 and Accuracy is 0.812500
# Batch   350: Loss per batch is 0.597645 and Accuracy is 0.828125
# Batch   400: Loss per batch is 0.763123 and Accuracy is 0.734375
# Batch   450: Loss per batch is 0.498382 and Accuracy is 0.859375
# Batch   500: Loss per batch is 0.767915 and Accuracy is 0.796875
# Batch   550: Loss per batch is 0.726416 and Accuracy is 0.718750
# Batch   600: Loss per batch is 0.599024 and Accuracy is 0.828125
# Batch   650: Loss per batch is 0.511837 and Accuracy is 0.765625
# Batch   700: Loss per batch is 0.733567 and Accuracy is 0.796875
# Batch   750: Loss per batch is 0.618908 and Accuracy is 0.812500
# For Iteration: Loss is 0.669877 and Accuracy is 0.777440
# ----Test: Epoch 6 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.78      0.84      0.81      1000
#   automobile       0.88      0.91      0.89      1000
#         bird       0.71      0.64      0.67      1000
#          cat       0.73      0.54      0.62      1000
#         deer       0.77      0.74      0.76      1000
#          dog       0.69      0.79      0.74      1000
#         frog       0.67      0.92      0.78      1000
#        horse       0.85      0.82      0.84      1000
#         ship       0.89      0.88      0.88      1000
#        truck       0.94      0.77      0.84      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.79      0.79      0.78     10000
# weighted avg       0.79      0.79      0.78     10000
#
# Training: Epoch 7 ------------------
# Batch     0: Loss per batch is 0.623617 and Accuracy is 0.796875
# Batch    50: Loss per batch is 0.778050 and Accuracy is 0.718750
# Batch   100: Loss per batch is 0.807976 and Accuracy is 0.687500
# Batch   150: Loss per batch is 0.803480 and Accuracy is 0.765625
# Batch   200: Loss per batch is 0.707952 and Accuracy is 0.796875
# Batch   250: Loss per batch is 0.632574 and Accuracy is 0.781250
# Batch   300: Loss per batch is 0.655611 and Accuracy is 0.812500
# Batch   350: Loss per batch is 0.598527 and Accuracy is 0.828125
# Batch   400: Loss per batch is 0.921007 and Accuracy is 0.703125
# Batch   450: Loss per batch is 0.512559 and Accuracy is 0.843750
# Batch   500: Loss per batch is 0.651999 and Accuracy is 0.828125
# Batch   550: Loss per batch is 0.826585 and Accuracy is 0.656250
# Batch   600: Loss per batch is 0.751585 and Accuracy is 0.750000
# Batch   650: Loss per batch is 0.759630 and Accuracy is 0.734375
# Batch   700: Loss per batch is 0.639755 and Accuracy is 0.796875
# Batch   750: Loss per batch is 0.548007 and Accuracy is 0.812500
# For Iteration: Loss is 0.724727 and Accuracy is 0.765680
# ----Test: Epoch 7 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.80      0.80      1000
#   automobile       0.92      0.86      0.89      1000
#         bird       0.78      0.62      0.69      1000
#          cat       0.55      0.77      0.64      1000
#         deer       0.82      0.72      0.77      1000
#          dog       0.92      0.44      0.60      1000
#         frog       0.80      0.87      0.84      1000
#        horse       0.71      0.91      0.80      1000
#         ship       0.73      0.95      0.83      1000
#        truck       0.94      0.80      0.86      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.80      0.77      0.77     10000
# weighted avg       0.80      0.77      0.77     10000
#
# Training: Epoch 8 ------------------
# Batch     0: Loss per batch is 0.321570 and Accuracy is 0.921875
# Batch    50: Loss per batch is 0.625642 and Accuracy is 0.812500
# Batch   100: Loss per batch is 0.763291 and Accuracy is 0.765625
# Batch   150: Loss per batch is 0.461187 and Accuracy is 0.921875
# Batch   200: Loss per batch is 0.528289 and Accuracy is 0.796875
# Batch   250: Loss per batch is 0.451656 and Accuracy is 0.812500
# Batch   300: Loss per batch is 0.349308 and Accuracy is 0.937500
# Batch   350: Loss per batch is 0.535132 and Accuracy is 0.875000
# Batch   400: Loss per batch is 0.569158 and Accuracy is 0.828125
# Batch   450: Loss per batch is 0.359164 and Accuracy is 0.921875
# Batch   500: Loss per batch is 0.553316 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.543501 and Accuracy is 0.765625
# Batch   600: Loss per batch is 0.710428 and Accuracy is 0.750000
# Batch   650: Loss per batch is 0.672037 and Accuracy is 0.812500
# Batch   700: Loss per batch is 0.508150 and Accuracy is 0.796875
# Batch   750: Loss per batch is 0.424386 and Accuracy is 0.812500
# For Iteration: Loss is 0.488484 and Accuracy is 0.841440
# ----Test: Epoch 8 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.80      0.80      1000
#   automobile       0.94      0.89      0.91      1000
#         bird       0.64      0.82      0.72      1000
#          cat       0.77      0.59      0.67      1000
#         deer       0.91      0.68      0.78      1000
#          dog       0.77      0.74      0.76      1000
#         frog       0.82      0.88      0.85      1000
#        horse       0.87      0.82      0.85      1000
#         ship       0.81      0.94      0.87      1000
#        truck       0.82      0.94      0.88      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 9 ------------------
# Batch     0: Loss per batch is 0.541479 and Accuracy is 0.812500
# Batch    50: Loss per batch is 0.472722 and Accuracy is 0.843750
# Batch   100: Loss per batch is 0.285909 and Accuracy is 0.906250
# Batch   150: Loss per batch is 0.708091 and Accuracy is 0.781250
# Batch   200: Loss per batch is 0.488129 and Accuracy is 0.859375
# Batch   250: Loss per batch is 0.509223 and Accuracy is 0.828125
# Batch   300: Loss per batch is 0.532549 and Accuracy is 0.828125
# Batch   350: Loss per batch is 0.778037 and Accuracy is 0.718750
# Batch   400: Loss per batch is 0.593209 and Accuracy is 0.781250
# Batch   450: Loss per batch is 0.476085 and Accuracy is 0.812500
# Batch   500: Loss per batch is 0.502122 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.410867 and Accuracy is 0.843750
# Batch   600: Loss per batch is 0.612160 and Accuracy is 0.781250
# Batch   650: Loss per batch is 0.576848 and Accuracy is 0.812500
# Batch   700: Loss per batch is 0.482985 and Accuracy is 0.890625
# Batch   750: Loss per batch is 0.560047 and Accuracy is 0.765625
# For Iteration: Loss is 0.547439 and Accuracy is 0.822720
# ----Test: Epoch 9 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.68      0.92      0.78      1000
#   automobile       0.95      0.83      0.89      1000
#         bird       0.70      0.73      0.71      1000
#          cat       0.54      0.79      0.64      1000
#         deer       0.76      0.80      0.78      1000
#          dog       0.97      0.41      0.58      1000
#         frog       0.92      0.74      0.82      1000
#        horse       0.88      0.82      0.85      1000
#         ship       0.88      0.87      0.87      1000
#        truck       0.85      0.91      0.88      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.81      0.78      0.78     10000
# weighted avg       0.81      0.78      0.78     10000
#
# Training: Epoch 10 ------------------
# Batch     0: Loss per batch is 0.576410 and Accuracy is 0.843750
# Batch    50: Loss per batch is 0.457297 and Accuracy is 0.859375
# Batch   100: Loss per batch is 0.661315 and Accuracy is 0.781250
# Batch   150: Loss per batch is 0.805170 and Accuracy is 0.734375
# Batch   200: Loss per batch is 0.586574 and Accuracy is 0.796875
# Batch   250: Loss per batch is 0.414139 and Accuracy is 0.906250
# Batch   300: Loss per batch is 0.502160 and Accuracy is 0.843750
# Batch   350: Loss per batch is 0.507489 and Accuracy is 0.812500
# Batch   400: Loss per batch is 0.627389 and Accuracy is 0.828125
# Batch   450: Loss per batch is 0.407452 and Accuracy is 0.906250
# Batch   500: Loss per batch is 0.607021 and Accuracy is 0.796875
# Batch   550: Loss per batch is 0.452845 and Accuracy is 0.843750
# Batch   600: Loss per batch is 0.488673 and Accuracy is 0.796875
# Batch   650: Loss per batch is 0.496188 and Accuracy is 0.843750
# Batch   700: Loss per batch is 0.340321 and Accuracy is 0.906250
# Batch   750: Loss per batch is 0.533226 and Accuracy is 0.828125
# For Iteration: Loss is 0.574765 and Accuracy is 0.818680
# ----Test: Epoch 10 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.86      0.82      1000
#   automobile       0.88      0.95      0.92      1000
#         bird       0.77      0.69      0.73      1000
#          cat       0.75      0.63      0.68      1000
#         deer       0.75      0.85      0.80      1000
#          dog       0.82      0.70      0.76      1000
#         frog       0.72      0.92      0.81      1000
#        horse       0.87      0.86      0.86      1000
#         ship       0.92      0.87      0.89      1000
#        truck       0.93      0.86      0.90      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000
#
# Training: Epoch 11 ------------------
# Batch     0: Loss per batch is 0.158913 and Accuracy is 0.968750
# Batch    50: Loss per batch is 0.180639 and Accuracy is 0.984375
# Batch   100: Loss per batch is 0.204867 and Accuracy is 0.937500
# Batch   150: Loss per batch is 0.311939 and Accuracy is 0.953125
# Batch   200: Loss per batch is 0.388106 and Accuracy is 0.812500
# Batch   250: Loss per batch is 0.271174 and Accuracy is 0.921875
# Batch   300: Loss per batch is 0.234962 and Accuracy is 0.937500
# Batch   350: Loss per batch is 0.437698 and Accuracy is 0.890625
# Batch   400: Loss per batch is 0.200685 and Accuracy is 0.968750
# Batch   450: Loss per batch is 0.155130 and Accuracy is 0.968750
# Batch   500: Loss per batch is 0.170331 and Accuracy is 0.953125
# Batch   550: Loss per batch is 0.419577 and Accuracy is 0.875000
# Batch   600: Loss per batch is 0.231974 and Accuracy is 0.937500
# Batch   650: Loss per batch is 0.326257 and Accuracy is 0.875000
# Batch   700: Loss per batch is 0.310855 and Accuracy is 0.906250
# Batch   750: Loss per batch is 0.357870 and Accuracy is 0.890625
# For Iteration: Loss is 0.292181 and Accuracy is 0.909760
# ----Test: Epoch 11 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.78      0.89      0.83      1000
#   automobile       0.94      0.93      0.93      1000
#         bird       0.79      0.68      0.73      1000
#          cat       0.61      0.76      0.68      1000
#         deer       0.92      0.66      0.77      1000
#          dog       0.79      0.70      0.74      1000
#         frog       0.73      0.92      0.81      1000
#        horse       0.89      0.83      0.86      1000
#         ship       0.94      0.86      0.90      1000
#        truck       0.85      0.92      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.83      0.81      0.81     10000
# weighted avg       0.83      0.81      0.81     10000
#
# Training: Epoch 12 ------------------
# Batch     0: Loss per batch is 0.506731 and Accuracy is 0.859375
# Batch    50: Loss per batch is 0.732982 and Accuracy is 0.765625
# Batch   100: Loss per batch is 0.588452 and Accuracy is 0.843750
# Batch   150: Loss per batch is 0.587718 and Accuracy is 0.781250
# Batch   200: Loss per batch is 0.406985 and Accuracy is 0.875000
# Batch   250: Loss per batch is 0.537384 and Accuracy is 0.843750
# Batch   300: Loss per batch is 0.499425 and Accuracy is 0.859375
# Batch   350: Loss per batch is 0.590019 and Accuracy is 0.781250
# Batch   400: Loss per batch is 0.565007 and Accuracy is 0.781250
# Batch   450: Loss per batch is 0.729503 and Accuracy is 0.812500
# Batch   500: Loss per batch is 0.667179 and Accuracy is 0.796875
# Batch   550: Loss per batch is 0.558280 and Accuracy is 0.812500
# Batch   600: Loss per batch is 0.562281 and Accuracy is 0.828125
# Batch   650: Loss per batch is 0.218631 and Accuracy is 0.937500
# Batch   700: Loss per batch is 0.552328 and Accuracy is 0.843750
# Batch   750: Loss per batch is 0.531377 and Accuracy is 0.890625
# For Iteration: Loss is 0.541362 and Accuracy is 0.828660
# ----Test: Epoch 12 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.84      0.83      1000
#   automobile       0.90      0.95      0.92      1000
#         bird       0.84      0.66      0.74      1000
#          cat       0.71      0.69      0.70      1000
#         deer       0.72      0.90      0.80      1000
#          dog       0.82      0.73      0.77      1000
#         frog       0.82      0.91      0.86      1000
#        horse       0.91      0.80      0.85      1000
#         ship       0.88      0.92      0.90      1000
#        truck       0.91      0.90      0.91      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000
#
# Training: Epoch 13 ------------------
# Batch     0: Loss per batch is 0.445897 and Accuracy is 0.828125
# Batch    50: Loss per batch is 0.305565 and Accuracy is 0.875000
# Batch   100: Loss per batch is 0.489734 and Accuracy is 0.859375
# Batch   150: Loss per batch is 0.388391 and Accuracy is 0.875000
# Batch   200: Loss per batch is 0.350016 and Accuracy is 0.906250
# Batch   250: Loss per batch is 0.570310 and Accuracy is 0.859375
# Batch   300: Loss per batch is 0.342741 and Accuracy is 0.890625
# Batch   350: Loss per batch is 0.423306 and Accuracy is 0.843750
# Batch   400: Loss per batch is 0.496267 and Accuracy is 0.859375
# Batch   450: Loss per batch is 0.500432 and Accuracy is 0.843750
# Batch   500: Loss per batch is 0.341407 and Accuracy is 0.921875
# Batch   550: Loss per batch is 0.348079 and Accuracy is 0.890625
# Batch   600: Loss per batch is 0.657017 and Accuracy is 0.750000
# Batch   650: Loss per batch is 0.439695 and Accuracy is 0.906250
# Batch   700: Loss per batch is 0.268067 and Accuracy is 0.890625
# Batch   750: Loss per batch is 0.454884 and Accuracy is 0.875000
# For Iteration: Loss is 0.436280 and Accuracy is 0.866740
# ----Test: Epoch 13 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.85      0.83      1000
#   automobile       0.87      0.95      0.91      1000
#         bird       0.79      0.73      0.76      1000
#          cat       0.78      0.59      0.67      1000
#         deer       0.87      0.74      0.80      1000
#          dog       0.71      0.81      0.76      1000
#         frog       0.76      0.94      0.84      1000
#        horse       0.87      0.85      0.86      1000
#         ship       0.86      0.93      0.90      1000
#        truck       0.93      0.83      0.88      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 14 ------------------
# Batch     0: Loss per batch is 0.182608 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.260511 and Accuracy is 0.937500
# Batch   100: Loss per batch is 0.109849 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.261951 and Accuracy is 0.890625
# Batch   200: Loss per batch is 0.185342 and Accuracy is 0.953125
# Batch   250: Loss per batch is 0.076211 and Accuracy is 0.968750
# Batch   300: Loss per batch is 0.227845 and Accuracy is 0.875000
# Batch   350: Loss per batch is 0.162229 and Accuracy is 0.968750
# Batch   400: Loss per batch is 0.338935 and Accuracy is 0.890625
# Batch   450: Loss per batch is 0.331757 and Accuracy is 0.906250
# Batch   500: Loss per batch is 0.328773 and Accuracy is 0.859375
# Batch   550: Loss per batch is 0.247768 and Accuracy is 0.921875
# Batch   600: Loss per batch is 0.142566 and Accuracy is 0.953125
# Batch   650: Loss per batch is 0.095656 and Accuracy is 0.984375
# Batch   700: Loss per batch is 0.175071 and Accuracy is 0.921875
# Batch   750: Loss per batch is 0.165099 and Accuracy is 0.984375
# For Iteration: Loss is 0.201300 and Accuracy is 0.942400
# ----Test: Epoch 14 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.87      0.84      1000
#   automobile       0.97      0.86      0.91      1000
#         bird       0.91      0.58      0.71      1000
#          cat       0.62      0.77      0.69      1000
#         deer       0.86      0.75      0.80      1000
#          dog       0.80      0.74      0.77      1000
#         frog       0.71      0.94      0.81      1000
#        horse       0.92      0.79      0.85      1000
#         ship       0.89      0.92      0.90      1000
#        truck       0.84      0.95      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 15 ------------------
# Batch     0: Loss per batch is 0.758819 and Accuracy is 0.734375
# Batch    50: Loss per batch is 0.771933 and Accuracy is 0.703125
# Batch   100: Loss per batch is 1.033175 and Accuracy is 0.625000
# Batch   150: Loss per batch is 0.620695 and Accuracy is 0.734375
# Batch   200: Loss per batch is 0.719874 and Accuracy is 0.781250
# Batch   250: Loss per batch is 0.626250 and Accuracy is 0.765625
# Batch   300: Loss per batch is 0.950827 and Accuracy is 0.765625
# Batch   350: Loss per batch is 0.559698 and Accuracy is 0.796875
# Batch   400: Loss per batch is 0.610303 and Accuracy is 0.781250
# Batch   450: Loss per batch is 0.612422 and Accuracy is 0.796875
# Batch   500: Loss per batch is 0.853388 and Accuracy is 0.750000
# Batch   550: Loss per batch is 0.438837 and Accuracy is 0.828125
# Batch   600: Loss per batch is 0.579499 and Accuracy is 0.796875
# Batch   650: Loss per batch is 0.627897 and Accuracy is 0.796875
# Batch   700: Loss per batch is 0.587375 and Accuracy is 0.781250
# Batch   750: Loss per batch is 0.765409 and Accuracy is 0.750000
# For Iteration: Loss is 0.659745 and Accuracy is 0.778700
# ----Test: Epoch 15 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.81      0.83      0.82      1000
#   automobile       0.94      0.86      0.90      1000
#         bird       0.82      0.62      0.71      1000
#          cat       0.68      0.72      0.70      1000
#         deer       0.80      0.81      0.80      1000
#          dog       0.75      0.79      0.77      1000
#         frog       0.87      0.83      0.85      1000
#        horse       0.85      0.88      0.87      1000
#         ship       0.92      0.86      0.89      1000
#        truck       0.77      0.96      0.85      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.81     10000
# weighted avg       0.82      0.82      0.81     10000
#
# Training: Epoch 16 ------------------
# Batch     0: Loss per batch is 0.268744 and Accuracy is 0.921875
# Batch    50: Loss per batch is 0.321469 and Accuracy is 0.906250
# Batch   100: Loss per batch is 0.421238 and Accuracy is 0.906250
# Batch   150: Loss per batch is 0.251911 and Accuracy is 0.968750
# Batch   200: Loss per batch is 0.174424 and Accuracy is 0.937500
# Batch   250: Loss per batch is 0.287754 and Accuracy is 0.937500
# Batch   300: Loss per batch is 0.342416 and Accuracy is 0.906250
# Batch   350: Loss per batch is 0.247964 and Accuracy is 0.968750
# Batch   400: Loss per batch is 0.328294 and Accuracy is 0.921875
# Batch   450: Loss per batch is 0.344160 and Accuracy is 0.906250
# Batch   500: Loss per batch is 0.137660 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.342867 and Accuracy is 0.906250
# Batch   600: Loss per batch is 0.235251 and Accuracy is 0.906250
# Batch   650: Loss per batch is 0.239581 and Accuracy is 0.937500
# Batch   700: Loss per batch is 0.222611 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.345688 and Accuracy is 0.906250
# For Iteration: Loss is 0.265970 and Accuracy is 0.925320
# ----Test: Epoch 16 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.78      0.89      0.83      1000
#   automobile       0.95      0.88      0.91      1000
#         bird       0.69      0.82      0.75      1000
#          cat       0.64      0.81      0.71      1000
#         deer       0.82      0.83      0.82      1000
#          dog       0.89      0.62      0.73      1000
#         frog       0.93      0.80      0.86      1000
#        horse       0.90      0.84      0.87      1000
#         ship       0.95      0.86      0.90      1000
#        truck       0.86      0.93      0.89      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Training: Epoch 17 ------------------
# Batch     0: Loss per batch is 0.140267 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.212989 and Accuracy is 0.953125
# Batch   100: Loss per batch is 0.221069 and Accuracy is 0.921875
# Batch   150: Loss per batch is 0.258217 and Accuracy is 0.937500
# Batch   200: Loss per batch is 0.271801 and Accuracy is 0.906250
# Batch   250: Loss per batch is 0.178025 and Accuracy is 0.937500
# Batch   300: Loss per batch is 0.201580 and Accuracy is 0.921875
# Batch   350: Loss per batch is 0.294943 and Accuracy is 0.875000
# Batch   400: Loss per batch is 0.244691 and Accuracy is 0.953125
# Batch   450: Loss per batch is 0.136726 and Accuracy is 0.937500
# Batch   500: Loss per batch is 0.196200 and Accuracy is 0.953125
# Batch   550: Loss per batch is 0.202558 and Accuracy is 0.953125
# Batch   600: Loss per batch is 0.303390 and Accuracy is 0.921875
# Batch   650: Loss per batch is 0.176537 and Accuracy is 0.968750
# Batch   700: Loss per batch is 0.320621 and Accuracy is 0.906250
# Batch   750: Loss per batch is 0.241523 and Accuracy is 0.937500
# For Iteration: Loss is 0.260369 and Accuracy is 0.924380
# ----Test: Epoch 17 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.78      0.90      0.83      1000
#   automobile       0.93      0.92      0.93      1000
#         bird       0.75      0.77      0.76      1000
#          cat       0.71      0.67      0.69      1000
#         deer       0.85      0.75      0.80      1000
#          dog       0.70      0.76      0.73      1000
#         frog       0.83      0.87      0.85      1000
#        horse       0.90      0.79      0.84      1000
#         ship       0.88      0.93      0.90      1000
#        truck       0.93      0.88      0.90      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
#
# Training: Epoch 18 ------------------
# Batch     0: Loss per batch is 0.878118 and Accuracy is 0.640625
# Batch    50: Loss per batch is 0.956913 and Accuracy is 0.671875
# Batch   100: Loss per batch is 0.695608 and Accuracy is 0.718750
# Batch   150: Loss per batch is 0.754001 and Accuracy is 0.734375
# Batch   200: Loss per batch is 0.883872 and Accuracy is 0.640625
# Batch   250: Loss per batch is 0.635708 and Accuracy is 0.734375
# Batch   300: Loss per batch is 0.708609 and Accuracy is 0.734375
# Batch   350: Loss per batch is 0.611522 and Accuracy is 0.750000
# Batch   400: Loss per batch is 0.765449 and Accuracy is 0.765625
# Batch   450: Loss per batch is 0.820448 and Accuracy is 0.703125
# Batch   500: Loss per batch is 0.744635 and Accuracy is 0.703125
# Batch   550: Loss per batch is 0.739577 and Accuracy is 0.734375
# Batch   600: Loss per batch is 0.641119 and Accuracy is 0.750000
# Batch   650: Loss per batch is 1.061766 and Accuracy is 0.687500
# Batch   700: Loss per batch is 0.638093 and Accuracy is 0.781250
# Batch   750: Loss per batch is 0.926607 and Accuracy is 0.687500
# For Iteration: Loss is 0.791968 and Accuracy is 0.717380
# ----Test: Epoch 18 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.76      0.89      0.82      1000
#   automobile       0.88      0.96      0.92      1000
#         bird       0.59      0.85      0.70      1000
#          cat       0.62      0.75      0.68      1000
#         deer       0.87      0.61      0.71      1000
#          dog       0.93      0.39      0.55      1000
#         frog       0.87      0.84      0.85      1000
#        horse       0.79      0.87      0.83      1000
#         ship       0.90      0.90      0.90      1000
#        truck       0.94      0.85      0.89      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.82      0.79      0.78     10000
# weighted avg       0.82      0.79      0.78     10000
#
# Training: Epoch 19 ------------------
# Batch     0: Loss per batch is 0.238992 and Accuracy is 0.968750
# Batch    50: Loss per batch is 0.182091 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.081366 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.242182 and Accuracy is 0.906250
# Batch   200: Loss per batch is 0.180637 and Accuracy is 0.968750
# Batch   250: Loss per batch is 0.125775 and Accuracy is 0.953125
# Batch   300: Loss per batch is 0.104125 and Accuracy is 0.968750
# Batch   350: Loss per batch is 0.197491 and Accuracy is 0.968750
# Batch   400: Loss per batch is 0.272655 and Accuracy is 0.937500
# Batch   450: Loss per batch is 0.183946 and Accuracy is 0.921875
# Batch   500: Loss per batch is 0.181915 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.249358 and Accuracy is 0.921875
# Batch   600: Loss per batch is 0.213623 and Accuracy is 0.921875
# Batch   650: Loss per batch is 0.104947 and Accuracy is 0.968750
# Batch   700: Loss per batch is 0.156743 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.087538 and Accuracy is 0.984375
# For Iteration: Loss is 0.152105 and Accuracy is 0.962680
# ----Test: Epoch 19 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.75      0.86      0.80      1000
#   automobile       0.92      0.93      0.92      1000
#         bird       0.89      0.56      0.69      1000
#          cat       0.75      0.62      0.68      1000
#         deer       0.89      0.67      0.77      1000
#          dog       0.73      0.80      0.76      1000
#         frog       0.82      0.90      0.85      1000
#        horse       0.73      0.93      0.82      1000
#         ship       0.79      0.95      0.86      1000
#        truck       0.93      0.87      0.90      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 20 ------------------
# Batch     0: Loss per batch is 0.405344 and Accuracy is 0.828125
# Batch    50: Loss per batch is 0.427793 and Accuracy is 0.859375
# Batch   100: Loss per batch is 0.661109 and Accuracy is 0.828125
# Batch   150: Loss per batch is 0.636156 and Accuracy is 0.796875
# Batch   200: Loss per batch is 0.407126 and Accuracy is 0.859375
# Batch   250: Loss per batch is 0.626707 and Accuracy is 0.750000
# Batch   300: Loss per batch is 0.282216 and Accuracy is 0.921875
# Batch   350: Loss per batch is 0.373008 and Accuracy is 0.890625
# Batch   400: Loss per batch is 0.304621 and Accuracy is 0.906250
# Batch   450: Loss per batch is 0.472783 and Accuracy is 0.843750
# Batch   500: Loss per batch is 0.541997 and Accuracy is 0.843750
# Batch   550: Loss per batch is 0.321370 and Accuracy is 0.906250
# Batch   600: Loss per batch is 0.410816 and Accuracy is 0.843750
# Batch   650: Loss per batch is 0.320441 and Accuracy is 0.859375
# Batch   700: Loss per batch is 0.407972 and Accuracy is 0.843750
# Batch   750: Loss per batch is 0.540751 and Accuracy is 0.796875
# For Iteration: Loss is 0.506974 and Accuracy is 0.824920
# ----Test: Epoch 20 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.87      0.79      0.83      1000
#   automobile       0.96      0.85      0.90      1000
#         bird       0.88      0.56      0.68      1000
#          cat       0.64      0.75      0.69      1000
#         deer       0.78      0.79      0.79      1000
#          dog       0.78      0.70      0.74      1000
#         frog       0.82      0.88      0.85      1000
#        horse       0.75      0.92      0.82      1000
#         ship       0.89      0.91      0.90      1000
#        truck       0.80      0.95      0.87      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 21 ------------------
# Batch     0: Loss per batch is 0.694876 and Accuracy is 0.718750
# Batch    50: Loss per batch is 0.724075 and Accuracy is 0.765625
# Batch   100: Loss per batch is 0.623945 and Accuracy is 0.796875
# Batch   150: Loss per batch is 0.668752 and Accuracy is 0.734375
# Batch   200: Loss per batch is 1.110830 and Accuracy is 0.625000
# Batch   250: Loss per batch is 0.649367 and Accuracy is 0.718750
# Batch   300: Loss per batch is 0.877548 and Accuracy is 0.687500
# Batch   350: Loss per batch is 0.685598 and Accuracy is 0.718750
# Batch   400: Loss per batch is 0.847018 and Accuracy is 0.703125
# Batch   450: Loss per batch is 0.748149 and Accuracy is 0.750000
# Batch   500: Loss per batch is 0.705966 and Accuracy is 0.718750
# Batch   550: Loss per batch is 0.699906 and Accuracy is 0.656250
# Batch   600: Loss per batch is 0.804191 and Accuracy is 0.687500
# Batch   650: Loss per batch is 0.796105 and Accuracy is 0.640625
# Batch   700: Loss per batch is 0.602948 and Accuracy is 0.765625
# Batch   750: Loss per batch is 0.780755 and Accuracy is 0.656250
# For Iteration: Loss is 0.792143 and Accuracy is 0.704380
# ----Test: Epoch 21 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.86      0.84      1000
#   automobile       0.86      0.94      0.90      1000
#         bird       0.79      0.65      0.71      1000
#          cat       0.77      0.58      0.66      1000
#         deer       0.85      0.69      0.76      1000
#          dog       0.62      0.84      0.72      1000
#         frog       0.69      0.93      0.79      1000
#        horse       0.93      0.76      0.84      1000
#         ship       0.89      0.90      0.90      1000
#        truck       0.92      0.85      0.88      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.80      0.80     10000
#
# Training: Epoch 22 ------------------
# Batch     0: Loss per batch is 0.191584 and Accuracy is 0.968750
# Batch    50: Loss per batch is 0.277370 and Accuracy is 0.937500
# Batch   100: Loss per batch is 0.150061 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.072272 and Accuracy is 1.000000
# Batch   200: Loss per batch is 0.044355 and Accuracy is 1.000000
# Batch   250: Loss per batch is 0.124132 and Accuracy is 0.984375
# Batch   300: Loss per batch is 0.097484 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.101984 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.101204 and Accuracy is 0.968750
# Batch   450: Loss per batch is 0.128320 and Accuracy is 0.953125
# Batch   500: Loss per batch is 0.108167 and Accuracy is 0.968750
# Batch   550: Loss per batch is 0.542469 and Accuracy is 0.890625
# Batch   600: Loss per batch is 0.148994 and Accuracy is 0.968750
# Batch   650: Loss per batch is 0.170924 and Accuracy is 0.937500
# Batch   700: Loss per batch is 0.064156 and Accuracy is 0.968750
# Batch   750: Loss per batch is 0.069482 and Accuracy is 0.984375
# For Iteration: Loss is 0.106892 and Accuracy is 0.974700
# ----Test: Epoch 22 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.77      0.87      0.82      1000
#   automobile       0.92      0.94      0.93      1000
#         bird       0.85      0.61      0.71      1000
#          cat       0.68      0.71      0.70      1000
#         deer       0.77      0.88      0.82      1000
#          dog       0.80      0.71      0.75      1000
#         frog       0.87      0.86      0.87      1000
#        horse       0.88      0.83      0.86      1000
#         ship       0.85      0.94      0.89      1000
#        truck       0.91      0.89      0.90      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.82     10000
# weighted avg       0.83      0.83      0.82     10000
#
# Training: Epoch 23 ------------------
# Batch     0: Loss per batch is 0.901203 and Accuracy is 0.640625
# Batch    50: Loss per batch is 0.928965 and Accuracy is 0.656250
# Batch   100: Loss per batch is 0.852215 and Accuracy is 0.640625
# Batch   150: Loss per batch is 1.121354 and Accuracy is 0.625000
# Batch   200: Loss per batch is 0.615414 and Accuracy is 0.734375
# Batch   250: Loss per batch is 1.140654 and Accuracy is 0.656250
# Batch   300: Loss per batch is 1.112014 and Accuracy is 0.625000
# Batch   350: Loss per batch is 1.085803 and Accuracy is 0.578125
# Batch   400: Loss per batch is 1.282038 and Accuracy is 0.515625
# Batch   450: Loss per batch is 0.703845 and Accuracy is 0.734375
# Batch   500: Loss per batch is 0.570725 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.829697 and Accuracy is 0.640625
# Batch   600: Loss per batch is 0.792795 and Accuracy is 0.687500
# Batch   650: Loss per batch is 1.102610 and Accuracy is 0.593750
# Batch   700: Loss per batch is 1.114731 and Accuracy is 0.562500
# Batch   750: Loss per batch is 1.005048 and Accuracy is 0.625000
# For Iteration: Loss is 0.954025 and Accuracy is 0.644260
# ----Test: Epoch 23 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.70      0.90      0.79      1000
#   automobile       0.93      0.91      0.92      1000
#         bird       0.84      0.59      0.69      1000
#          cat       0.53      0.79      0.63      1000
#         deer       0.77      0.78      0.77      1000
#          dog       0.76      0.67      0.72      1000
#         frog       0.92      0.74      0.82      1000
#        horse       0.83      0.85      0.84      1000
#         ship       0.95      0.81      0.88      1000
#        truck       0.90      0.89      0.90      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.80     10000
# weighted avg       0.81      0.79      0.80     10000
#
# Training: Epoch 24 ------------------
# Batch     0: Loss per batch is 0.684615 and Accuracy is 0.781250
# Batch    50: Loss per batch is 0.810180 and Accuracy is 0.703125
# Batch   100: Loss per batch is 0.500525 and Accuracy is 0.828125
# Batch   150: Loss per batch is 0.614879 and Accuracy is 0.765625
# Batch   200: Loss per batch is 0.763928 and Accuracy is 0.656250
# Batch   250: Loss per batch is 0.708638 and Accuracy is 0.796875
# Batch   300: Loss per batch is 0.552270 and Accuracy is 0.812500
# Batch   350: Loss per batch is 0.562333 and Accuracy is 0.781250
# Batch   400: Loss per batch is 0.749661 and Accuracy is 0.703125
# Batch   450: Loss per batch is 0.685212 and Accuracy is 0.718750
# Batch   500: Loss per batch is 0.489759 and Accuracy is 0.812500
# Batch   550: Loss per batch is 0.582492 and Accuracy is 0.781250
# Batch   600: Loss per batch is 0.627549 and Accuracy is 0.796875
# Batch   650: Loss per batch is 0.861902 and Accuracy is 0.703125
# Batch   700: Loss per batch is 0.584364 and Accuracy is 0.734375
# Batch   750: Loss per batch is 0.534222 and Accuracy is 0.828125
# For Iteration: Loss is 0.693927 and Accuracy is 0.734380
# ----Test: Epoch 24 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.83      0.84      1000
#   automobile       0.85      0.96      0.90      1000
#         bird       0.82      0.67      0.74      1000
#          cat       0.71      0.66      0.69      1000
#         deer       0.83      0.76      0.79      1000
#          dog       0.67      0.81      0.73      1000
#         frog       0.77      0.92      0.84      1000
#        horse       0.90      0.81      0.85      1000
#         ship       0.89      0.93      0.91      1000
#        truck       0.94      0.84      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000
#
# Training: Epoch 25 ------------------
# Batch     0: Loss per batch is 0.163233 and Accuracy is 0.984375
# Batch    50: Loss per batch is 0.185197 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.051531 and Accuracy is 0.984375
# Batch   150: Loss per batch is 0.284193 and Accuracy is 0.890625
# Batch   200: Loss per batch is 0.062444 and Accuracy is 0.984375
# Batch   250: Loss per batch is 0.144425 and Accuracy is 0.968750
# Batch   300: Loss per batch is 0.152607 and Accuracy is 0.921875
# Batch   350: Loss per batch is 0.123233 and Accuracy is 0.984375
# Batch   400: Loss per batch is 0.065285 and Accuracy is 1.000000
# Batch   450: Loss per batch is 0.041263 and Accuracy is 1.000000
# Batch   500: Loss per batch is 0.094854 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.131870 and Accuracy is 0.937500
# Batch   600: Loss per batch is 0.241518 and Accuracy is 0.953125
# Batch   650: Loss per batch is 0.240139 and Accuracy is 0.953125
# Batch   700: Loss per batch is 0.195232 and Accuracy is 0.953125
# Batch   750: Loss per batch is 0.200168 and Accuracy is 0.937500
# For Iteration: Loss is 0.144132 and Accuracy is 0.965220
# ----Test: Epoch 25 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.90      0.79      0.84      1000
#   automobile       0.85      0.97      0.91      1000
#         bird       0.79      0.73      0.76      1000
#          cat       0.62      0.80      0.70      1000
#         deer       0.80      0.85      0.82      1000
#          dog       0.84      0.67      0.74      1000
#         frog       0.89      0.82      0.86      1000
#        horse       0.83      0.88      0.85      1000
#         ship       0.90      0.90      0.90      1000
#        truck       0.94      0.87      0.90      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Training: Epoch 26 ------------------
# Batch     0: Loss per batch is 1.271999 and Accuracy is 0.562500
# Batch    50: Loss per batch is 1.344251 and Accuracy is 0.421875
# Batch   100: Loss per batch is 1.133228 and Accuracy is 0.578125
# Batch   150: Loss per batch is 1.255238 and Accuracy is 0.531250
# Batch   200: Loss per batch is 1.234001 and Accuracy is 0.500000
# Batch   250: Loss per batch is 1.755899 and Accuracy is 0.421875
# Batch   300: Loss per batch is 1.398856 and Accuracy is 0.406250
# Batch   350: Loss per batch is 1.758366 and Accuracy is 0.406250
# Batch   400: Loss per batch is 1.002116 and Accuracy is 0.625000
# Batch   450: Loss per batch is 1.121248 and Accuracy is 0.625000
# Batch   500: Loss per batch is 1.419408 and Accuracy is 0.390625
# Batch   550: Loss per batch is 1.258483 and Accuracy is 0.531250
# Batch   600: Loss per batch is 1.266900 and Accuracy is 0.515625
# Batch   650: Loss per batch is 1.132379 and Accuracy is 0.515625
# Batch   700: Loss per batch is 1.272280 and Accuracy is 0.453125
# Batch   750: Loss per batch is 1.078499 and Accuracy is 0.593750
# For Iteration: Loss is 1.228938 and Accuracy is 0.515520
# ----Test: Epoch 26 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.81      0.85      0.83      1000
#   automobile       0.92      0.90      0.91      1000
#         bird       0.75      0.70      0.72      1000
#          cat       0.65      0.69      0.67      1000
#         deer       0.78      0.79      0.78      1000
#          dog       0.86      0.59      0.70      1000
#         frog       0.86      0.84      0.85      1000
#        horse       0.82      0.86      0.84      1000
#         ship       0.91      0.89      0.90      1000
#        truck       0.75      0.94      0.83      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.80     10000
# weighted avg       0.81      0.81      0.80     10000
#
# Training: Epoch 27 ------------------
# Batch     0: Loss per batch is 0.692794 and Accuracy is 0.812500
# Batch    50: Loss per batch is 0.488633 and Accuracy is 0.890625
# Batch   100: Loss per batch is 0.240511 and Accuracy is 0.968750
# Batch   150: Loss per batch is 0.430276 and Accuracy is 0.796875
# Batch   200: Loss per batch is 0.350031 and Accuracy is 0.875000
# Batch   250: Loss per batch is 0.378417 and Accuracy is 0.859375
# Batch   300: Loss per batch is 0.541690 and Accuracy is 0.796875
# Batch   350: Loss per batch is 0.406889 and Accuracy is 0.859375
# Batch   400: Loss per batch is 0.566215 and Accuracy is 0.765625
# Batch   450: Loss per batch is 0.339130 and Accuracy is 0.890625
# Batch   500: Loss per batch is 0.606959 and Accuracy is 0.781250
# Batch   550: Loss per batch is 0.453502 and Accuracy is 0.859375
# Batch   600: Loss per batch is 0.403809 and Accuracy is 0.875000
# Batch   650: Loss per batch is 0.577627 and Accuracy is 0.781250
# Batch   700: Loss per batch is 0.391762 and Accuracy is 0.859375
# Batch   750: Loss per batch is 0.544174 and Accuracy is 0.828125
# For Iteration: Loss is 0.473155 and Accuracy is 0.831780
# ----Test: Epoch 27 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.75      0.80      1000
#   automobile       0.90      0.95      0.92      1000
#         bird       0.77      0.67      0.72      1000
#          cat       0.79      0.56      0.65      1000
#         deer       0.83      0.74      0.78      1000
#          dog       0.76      0.75      0.76      1000
#         frog       0.71      0.93      0.80      1000
#        horse       0.83      0.89      0.86      1000
#         ship       0.80      0.95      0.87      1000
#        truck       0.88      0.90      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# Training: Epoch 28 ------------------
# Batch     0: Loss per batch is 0.442916 and Accuracy is 0.812500
# Batch    50: Loss per batch is 0.343766 and Accuracy is 0.890625
# Batch   100: Loss per batch is 0.395350 and Accuracy is 0.843750
# Batch   150: Loss per batch is 0.433973 and Accuracy is 0.843750
# Batch   200: Loss per batch is 0.248965 and Accuracy is 0.921875
# Batch   250: Loss per batch is 0.485860 and Accuracy is 0.781250
# Batch   300: Loss per batch is 0.547176 and Accuracy is 0.796875
# Batch   350: Loss per batch is 0.456852 and Accuracy is 0.859375
# Batch   400: Loss per batch is 0.583676 and Accuracy is 0.812500
# Batch   450: Loss per batch is 0.254723 and Accuracy is 0.906250
# Batch   500: Loss per batch is 0.209947 and Accuracy is 0.953125
# Batch   550: Loss per batch is 0.351396 and Accuracy is 0.906250
# Batch   600: Loss per batch is 0.457455 and Accuracy is 0.859375
# Batch   650: Loss per batch is 0.342385 and Accuracy is 0.921875
# Batch   700: Loss per batch is 0.352963 and Accuracy is 0.875000
# Batch   750: Loss per batch is 0.406440 and Accuracy is 0.828125
# For Iteration: Loss is 0.417187 and Accuracy is 0.849420
# ----Test: Epoch 28 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.82      0.85      0.83      1000
#   automobile       0.95      0.86      0.90      1000
#         bird       0.77      0.70      0.73      1000
#          cat       0.68      0.69      0.69      1000
#         deer       0.80      0.82      0.81      1000
#          dog       0.80      0.71      0.75      1000
#         frog       0.87      0.85      0.86      1000
#        horse       0.84      0.86      0.85      1000
#         ship       0.89      0.90      0.89      1000
#        truck       0.78      0.96      0.86      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000
#
# Training: Epoch 29 ------------------
# Batch     0: Loss per batch is 1.605610 and Accuracy is 0.484375
# Batch    50: Loss per batch is 1.568802 and Accuracy is 0.406250
# Batch   100: Loss per batch is 1.762592 and Accuracy is 0.312500
# Batch   150: Loss per batch is 1.287323 and Accuracy is 0.531250
# Batch   200: Loss per batch is 1.898763 and Accuracy is 0.296875
# Batch   250: Loss per batch is 1.515036 and Accuracy is 0.343750
# Batch   300: Loss per batch is 1.280960 and Accuracy is 0.390625
# Batch   350: Loss per batch is 1.227510 and Accuracy is 0.453125
# Batch   400: Loss per batch is 1.297163 and Accuracy is 0.515625
# Batch   450: Loss per batch is 1.363602 and Accuracy is 0.421875
# Batch   500: Loss per batch is 1.308412 and Accuracy is 0.421875
# Batch   550: Loss per batch is 1.161386 and Accuracy is 0.515625
# Batch   600: Loss per batch is 1.528004 and Accuracy is 0.375000
# Batch   650: Loss per batch is 1.543202 and Accuracy is 0.312500
# Batch   700: Loss per batch is 1.366170 and Accuracy is 0.437500
# Batch   750: Loss per batch is 1.312277 and Accuracy is 0.421875
# For Iteration: Loss is 1.358988 and Accuracy is 0.438280
# ----Test: Epoch 29 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.84      0.82      1000
#   automobile       0.91      0.92      0.92      1000
#         bird       0.77      0.70      0.74      1000
#          cat       0.64      0.72      0.68      1000
#         deer       0.83      0.76      0.79      1000
#          dog       0.74      0.74      0.74      1000
#         frog       0.81      0.88      0.84      1000
#        horse       0.88      0.83      0.85      1000
#         ship       0.95      0.81      0.87      1000
#        truck       0.86      0.93      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Training: Epoch 30 ------------------
# Batch     0: Loss per batch is 0.351447 and Accuracy is 0.953125
# Batch    50: Loss per batch is 0.197229 and Accuracy is 0.968750
# Batch   100: Loss per batch is 0.141454 and Accuracy is 1.000000
# Batch   150: Loss per batch is 0.148632 and Accuracy is 0.953125
# Batch   200: Loss per batch is 0.366886 and Accuracy is 0.843750
# Batch   250: Loss per batch is 0.213859 and Accuracy is 0.921875
# Batch   300: Loss per batch is 0.139679 and Accuracy is 0.984375
# Batch   350: Loss per batch is 0.134427 and Accuracy is 0.968750
# Batch   400: Loss per batch is 0.241855 and Accuracy is 0.968750
# Batch   450: Loss per batch is 0.126501 and Accuracy is 0.984375
# Batch   500: Loss per batch is 0.126947 and Accuracy is 0.984375
# Batch   550: Loss per batch is 0.295053 and Accuracy is 0.875000
# Batch   600: Loss per batch is 0.167835 and Accuracy is 0.953125
# Batch   650: Loss per batch is 0.248795 and Accuracy is 0.906250
# Batch   700: Loss per batch is 0.221928 and Accuracy is 0.937500
# Batch   750: Loss per batch is 0.141845 and Accuracy is 0.953125
# For Iteration: Loss is 0.215254 and Accuracy is 0.941640
# ----Test: Epoch 30 ------------------
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.86      0.83      1000
#   automobile       0.91      0.92      0.91      1000
#         bird       0.77      0.69      0.73      1000
#          cat       0.70      0.66      0.68      1000
#         deer       0.80      0.81      0.81      1000
#          dog       0.84      0.64      0.73      1000
#         frog       0.78      0.90      0.83      1000
#        horse       0.80      0.88      0.84      1000
#         ship       0.92      0.85      0.89      1000
#        truck       0.85      0.93      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.81     10000
# weighted avg       0.82      0.82      0.81     10000
